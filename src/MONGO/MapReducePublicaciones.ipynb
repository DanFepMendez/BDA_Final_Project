# %% [markdown]
# # MapReduce Publicaciones

# %%
###############################################################
#!/usr/bin/python
# Purpose: Migrate Products from MySQL to Mongo
# Dependecies : python-pip , pymongo , mysqldb
# apt-get install python-pip ; pip install pymongo;
# apt-get install python-MySQLdb


import pymongo
import datetime
import enum
from pprint import pprint

# %%
########################################################################################
mongodb_host            = 'mongodb://localhost:11111'
mongodb_dbname          = 'project_test'
n_collection            = 'registro_publicaciones'
#########################
mclient = pymongo.MongoClient(mongodb_host)
mdb = mclient[mongodb_dbname]

# %%
collections = mdb.list_collection_names()
print(collections)
# Out:
# ['programa', 'contrataciones_year', 'contrataciones_por_empresa', 'graduaciones_facultad', 'publicacion', 'time_', 'out_num_general_publications', 'registro_publicaciones', 'contrataciones_origen', 'out_num_publicaciones_x_institucion', 'facultad', 'out_num_publications_by_year', 'departamento', 'graduaciones', 'cargos', 'graduaciones_sede', 'graduaciones_tipo_programa', 'sede_universidad', 'empresa', 'revista', 'out_num_publications_by_sede', 'graduaciones_year', 'egresado', 'institucion', 'contrataciones']

# %%
publicaciones = mdb["registro_publicaciones"]
pprint(publicaciones.find()[0])
# Out:
# {'_id': ObjectId('662d7aad2c429704c8be4f10'),
#  'date_id': datetime.datetime(2009, 2, 4, 0, 0),
#  'egresado_id': {'egresado_address': '020 Kylie Ports Suite 899\n'
#                                      'New Christineport, KY 67527',
#                  'egresado_cellphone': '001-520-67',
#                  'egresado_edad': 26,
#                  'egresado_emailaddress': 'davisthomas@bullock.net',
#                  'egresado_etnicgroup': 'ACTIVO',
#                  'egresado_firstlastname': 'ALVAREZ',
#                  'egresado_gender': 'MASCULINO',
#                  'egresado_id': 58,
#                  'egresado_names': 'AMANDA',
#                  'egresado_secondlastname': 'PERKINS'},
#  'institucion_id': None,
#  'publicacion_id': {'ano_publiacion': datetime.datetime(2009, 2, 4, 0, 0),
#                     'descripcion': 'East east condition group commercial '
#                                    'letter practice determine. Hotel '
#                                    'Republican marriage we catch. Task rest '
#                                    'staff. Wife war campaign ready amount '
#                                    'agreement. Bar large career happy effort.',
#                     'publicacion_id': 360,
#                     'tipo_publicacion': 'Health.'},
#  'registration_id': 1,
#  'revista_id': {'revista_id': 82, 'revista_nombre': 'Article.'}}

# %%
# Tipo de Publicaciones General

stage_group_general_publications = {
  "$group": {
    "_id" : "$publicacion_id",
    "count_general_publicacions": {"$sum": 1}
  }
}

stage_out_general_publications = {
  "$out": "out_num_general_publications"
}

pipeline = [
  stage_group_general_publications,
  stage_out_general_publications
]

results = publicaciones.aggregate(pipeline)

for publicaciones_mapreduce in mdb["out_num_general_publications"].find():
  print(publicaciones_mapreduce)
# Out:
# {'_id': 888, 'count_general_publicacions': 1}
# {'_id': 686, 'count_general_publicacions': 1}
# {'_id': 144, 'count_general_publicacions': 1}
# {'_id': 521, 'count_general_publicacions': 1}
# {'_id': 915, 'count_general_publicacions': 1}
# {'_id': 676, 'count_general_publicacions': 1}
# {'_id': 980, 'count_general_publicacions': 1}
# {'_id': 691, 'count_general_publicacions': 1}
# {'_id': 704, 'count_general_publicacions': 1}
# {'_id': 26, 'count_general_publicacions': 1}
# {'_id': 554, 'count_general_publicacions': 1}
# {'_id': 228, 'count_general_publicacions': 1}
# {'_id': 885, 'count_general_publicacions': 1}
# {'_id': 537, 'count_general_publicacions': 1}
# {'_id': 267, 'count_general_publicacions': 1}
# {'_id': 14, 'count_general_publicacions': 1}
# {'_id': 130, 'count_general_publicacions': 1}
# {'_id': 63, 'count_general_publicacions': 1}
# {'_id': 626, 'count_general_publicacions': 1}
# {'_id': 284, 'count_general_publicacions': 1}
# {'_id': 146, 'count_general_publicacions': 1}
# {'_id': 434, 'count_general_publicacions': 1}
# {'_id': 838, 'count_general_publicacions': 1}
# {'_id': 967, 'count_general_publicacions': 1}
# {'_id': 747, 'count_general_publicacions': 1}
# {'_id': 473, 'count_general_publicacions': 1}
# {'_id': 357, 'count_general_publicacions': 1}
# {'_id': 750, 'count_general_publicacions': 1}
# {'_id': 448, 'count_general_publicacions': 1}
# {'_id': 45, 'count_general_publicacions': 1}
# {'_id': 753, 'count_general_publicacions': 1}
# {'_id': 816, 'count_general_publicacions': 1}
# {'_id': 470, 'count_general_publicacions': 1}
# {'_id': 705, 'count_general_publicacions': 1}
# {'_id': 257, 'count_general_publicacions': 1}
# {'_id': 189, 'count_general_publicacions': 1}
# {'_id': 482, 'count_general_publicacions': 1}
# {'_id': 874, 'count_general_publicacions': 1}
# {'_id': 987, 'count_general_publicacions': 1}
# {'_id': 225, 'count_general_publicacions': 1}
# {'_id': 672, 'count_general_publicacions': 1}
# {'_id': 79, 'count_general_publicacions': 1}
# {'_id': 432, 'count_general_publicacions': 1}
# {'_id': 289, 'count_general_publicacions': 1}
# {'_id': 771, 'count_general_publicacions': 1}
# {'_id': 765, 'count_general_publicacions': 1}
# {'_id': 415, 'count_general_publicacions': 1}
# {'_id': 321, 'count_general_publicacions': 1}
# {'_id': 436, 'count_general_publicacions': 1}
# {'_id': 561, 'count_general_publicacions': 1}
# {'_id': 669, 'count_general_publicacions': 1}
# {'_id': 412, 'count_general_publicacions': 1}
# {'_id': 994, 'count_general_publicacions': 1}
# {'_id': 748, 'count_general_publicacions': 1}
# {'_id': 160, 'count_general_publicacions': 1}
# {'_id': 501, 'count_general_publicacions': 1}
# {'_id': 793, 'count_general_publicacions': 1}
# {'_id': 630, 'count_general_publicacions': 1}
# {'_id': 832, 'count_general_publicacions': 1}
# {'_id': 879, 'count_general_publicacions': 1}
# {'_id': 814, 'count_general_publicacions': 1}
# {'_id': 282, 'count_general_publicacions': 1}
# {'_id': 108, 'count_general_publicacions': 1}
# {'_id': 899, 'count_general_publicacions': 1}
# {'_id': 19, 'count_general_publicacions': 1}
# {'_id': 541, 'count_general_publicacions': 1}
# {'_id': 318, 'count_general_publicacions': 1}
# {'_id': 804, 'count_general_publicacions': 1}
# {'_id': 649, 'count_general_publicacions': 1}
# {'_id': 751, 'count_general_publicacions': 1}
# {'_id': 389, 'count_general_publicacions': 1}
# {'_id': 517, 'count_general_publicacions': 1}
# {'_id': 545, 'count_general_publicacions': 1}
# {'_id': 363, 'count_general_publicacions': 1}
# {'_id': 9, 'count_general_publicacions': 1}
# {'_id': 768, 'count_general_publicacions': 1}
# {'_id': 208, 'count_general_publicacions': 1}
# {'_id': 354, 'count_general_publicacions': 1}
# {'_id': 251, 'count_general_publicacions': 1}
# {'_id': 203, 'count_general_publicacions': 1}
# {'_id': 280, 'count_general_publicacions': 1}
# {'_id': 853, 'count_general_publicacions': 1}
# {'_id': 655, 'count_general_publicacions': 1}
# {'_id': 849, 'count_general_publicacions': 1}
# {'_id': 220, 'count_general_publicacions': 1}
# {'_id': 191, 'count_general_publicacions': 1}
# {'_id': 827, 'count_general_publicacions': 1}
# {'_id': 677, 'count_general_publicacions': 1}
# {'_id': 710, 'count_general_publicacions': 1}
# {'_id': 859, 'count_general_publicacions': 1}
# {'_id': 377, 'count_general_publicacions': 1}
# {'_id': 349, 'count_general_publicacions': 1}
# {'_id': 618, 'count_general_publicacions': 1}
# {'_id': 28, 'count_general_publicacions': 1}
# {'_id': 829, 'count_general_publicacions': 1}
# {'_id': 238, 'count_general_publicacions': 1}
# {'_id': 85, 'count_general_publicacions': 1}
# {'_id': 196, 'count_general_publicacions': 1}
# {'_id': 795, 'count_general_publicacions': 1}
# {'_id': 281, 'count_general_publicacions': 1}
# {'_id': 216, 'count_general_publicacions': 1}
# {'_id': 229, 'count_general_publicacions': 1}
# {'_id': 60, 'count_general_publicacions': 1}
# {'_id': 304, 'count_general_publicacions': 1}
# {'_id': 193, 'count_general_publicacions': 1}
# {'_id': 353, 'count_general_publicacions': 1}
# {'_id': 197, 'count_general_publicacions': 1}
# {'_id': 821, 'count_general_publicacions': 1}
# {'_id': 42, 'count_general_publicacions': 1}
# {'_id': 947, 'count_general_publicacions': 1}
# {'_id': 334, 'count_general_publicacions': 1}
# {'_id': 285, 'count_general_publicacions': 1}
# {'_id': 798, 'count_general_publicacions': 1}
# {'_id': 265, 'count_general_publicacions': 1}
# {'_id': 11, 'count_general_publicacions': 1}
# {'_id': 549, 'count_general_publicacions': 1}
# {'_id': 621, 'count_general_publicacions': 1}
# {'_id': 819, 'count_general_publicacions': 1}
# {'_id': 772, 'count_general_publicacions': 1}
# {'_id': 489, 'count_general_publicacions': 1}
# {'_id': 323, 'count_general_publicacions': 1}
# {'_id': 654, 'count_general_publicacions': 1}
# {'_id': 601, 'count_general_publicacions': 1}
# {'_id': 565, 'count_general_publicacions': 1}
# {'_id': 884, 'count_general_publicacions': 1}
# {'_id': 348, 'count_general_publicacions': 1}
# {'_id': 692, 'count_general_publicacions': 1}
# {'_id': 882, 'count_general_publicacions': 1}
# {'_id': 588, 'count_general_publicacions': 1}
# {'_id': 636, 'count_general_publicacions': 1}
# {'_id': 694, 'count_general_publicacions': 1}
# {'_id': 236, 'count_general_publicacions': 1}
# {'_id': 525, 'count_general_publicacions': 1}
# {'_id': 139, 'count_general_publicacions': 1}
# {'_id': 180, 'count_general_publicacions': 1}
# {'_id': 145, 'count_general_publicacions': 1}
# {'_id': 984, 'count_general_publicacions': 1}
# {'_id': 81, 'count_general_publicacions': 1}
# {'_id': 509, 'count_general_publicacions': 1}
# {'_id': 306, 'count_general_publicacions': 1}
# {'_id': 416, 'count_general_publicacions': 1}
# {'_id': 88, 'count_general_publicacions': 1}
# {'_id': 387, 'count_general_publicacions': 1}
# {'_id': 399, 'count_general_publicacions': 1}
# {'_id': 185, 'count_general_publicacions': 1}
# {'_id': 248, 'count_general_publicacions': 1}
# {'_id': 662, 'count_general_publicacions': 1}
# {'_id': 274, 'count_general_publicacions': 1}
# {'_id': 927, 'count_general_publicacions': 1}
# {'_id': 496, 'count_general_publicacions': 1}
# {'_id': 928, 'count_general_publicacions': 1}
# {'_id': 539, 'count_general_publicacions': 1}
# {'_id': 756, 'count_general_publicacions': 1}
# {'_id': 782, 'count_general_publicacions': 1}
# {'_id': 18, 'count_general_publicacions': 1}
# {'_id': 312, 'count_general_publicacions': 1}
# {'_id': 689, 'count_general_publicacions': 1}
# {'_id': 211, 'count_general_publicacions': 1}
# {'_id': 303, 'count_general_publicacions': 1}
# {'_id': 406, 'count_general_publicacions': 1}
# {'_id': 559, 'count_general_publicacions': 1}
# {'_id': 361, 'count_general_publicacions': 1}
# {'_id': 420, 'count_general_publicacions': 1}
# {'_id': 65, 'count_general_publicacions': 1}
# {'_id': 760, 'count_general_publicacions': 1}
# {'_id': 785, 'count_general_publicacions': 1}
# {'_id': 158, 'count_general_publicacions': 1}
# {'_id': 982, 'count_general_publicacions': 1}
# {'_id': 818, 'count_general_publicacions': 1}
# {'_id': 101, 'count_general_publicacions': 1}
# {'_id': 207, 'count_general_publicacions': 1}
# {'_id': 187, 'count_general_publicacions': 1}
# {'_id': 370, 'count_general_publicacions': 1}
# {'_id': 176, 'count_general_publicacions': 1}
# {'_id': 739, 'count_general_publicacions': 1}
# {'_id': 497, 'count_general_publicacions': 1}
# {'_id': 553, 'count_general_publicacions': 1}
# {'_id': 218, 'count_general_publicacions': 1}
# {'_id': 226, 'count_general_publicacions': 1}
# {'_id': 986, 'count_general_publicacions': 1}
# {'_id': 469, 'count_general_publicacions': 1}
# {'_id': 388, 'count_general_publicacions': 1}
# {'_id': 486, 'count_general_publicacions': 1}
# {'_id': 95, 'count_general_publicacions': 1}
# {'_id': 586, 'count_general_publicacions': 1}
# {'_id': 567, 'count_general_publicacions': 1}
# {'_id': 84, 'count_general_publicacions': 1}
# {'_id': 477, 'count_general_publicacions': 1}
# {'_id': 269, 'count_general_publicacions': 1}
# {'_id': 235, 'count_general_publicacions': 1}
# {'_id': 871, 'count_general_publicacions': 1}
# {'_id': 678, 'count_general_publicacions': 1}
# {'_id': 569, 'count_general_publicacions': 1}
# {'_id': 214, 'count_general_publicacions': 1}
# {'_id': 671, 'count_general_publicacions': 1}
# {'_id': 563, 'count_general_publicacions': 1}
# {'_id': 157, 'count_general_publicacions': 1}
# {'_id': 532, 'count_general_publicacions': 1}
# {'_id': 661, 'count_general_publicacions': 1}
# {'_id': 516, 'count_general_publicacions': 1}
# {'_id': 343, 'count_general_publicacions': 1}
# {'_id': 797, 'count_general_publicacions': 1}
# {'_id': 440, 'count_general_publicacions': 1}
# {'_id': 371, 'count_general_publicacions': 1}
# {'_id': 498, 'count_general_publicacions': 1}
# {'_id': 946, 'count_general_publicacions': 1}
# {'_id': 856, 'count_general_publicacions': 1}
# {'_id': 398, 'count_general_publicacions': 1}
# {'_id': 414, 'count_general_publicacions': 1}
# {'_id': 423, 'count_general_publicacions': 1}
# {'_id': 439, 'count_general_publicacions': 1}
# {'_id': 174, 'count_general_publicacions': 1}
# {'_id': 834, 'count_general_publicacions': 1}
# {'_id': 737, 'count_general_publicacions': 1}
# {'_id': 729, 'count_general_publicacions': 1}
# {'_id': 164, 'count_general_publicacions': 1}
# {'_id': 960, 'count_general_publicacions': 1}
# {'_id': 258, 'count_general_publicacions': 1}
# {'_id': 682, 'count_general_publicacions': 1}
# {'_id': 905, 'count_general_publicacions': 1}
# {'_id': 492, 'count_general_publicacions': 1}
# {'_id': 76, 'count_general_publicacions': 1}
# {'_id': 127, 'count_general_publicacions': 1}
# {'_id': 580, 'count_general_publicacions': 1}
# {'_id': 922, 'count_general_publicacions': 1}
# {'_id': 147, 'count_general_publicacions': 1}
# {'_id': 557, 'count_general_publicacions': 1}
# {'_id': 607, 'count_general_publicacions': 1}
# {'_id': 948, 'count_general_publicacions': 1}
# {'_id': 47, 'count_general_publicacions': 1}
# {'_id': 481, 'count_general_publicacions': 1}
# {'_id': 350, 'count_general_publicacions': 1}
# {'_id': 774, 'count_general_publicacions': 1}
# {'_id': 148, 'count_general_publicacions': 1}
# {'_id': 325, 'count_general_publicacions': 1}
# {'_id': 595, 'count_general_publicacions': 1}
# {'_id': 628, 'count_general_publicacions': 1}
# {'_id': 719, 'count_general_publicacions': 1}
# {'_id': 338, 'count_general_publicacions': 1}
# {'_id': 342, 'count_general_publicacions': 1}
# {'_id': 603, 'count_general_publicacions': 1}
# {'_id': 270, 'count_general_publicacions': 1}
# {'_id': 697, 'count_general_publicacions': 1}
# {'_id': 7, 'count_general_publicacions': 1}
# {'_id': 845, 'count_general_publicacions': 1}
# {'_id': 637, 'count_general_publicacions': 1}
# {'_id': 867, 'count_general_publicacions': 1}
# {'_id': 903, 'count_general_publicacions': 1}
# {'_id': 20, 'count_general_publicacions': 1}
# {'_id': 758, 'count_general_publicacions': 1}
# {'_id': 43, 'count_general_publicacions': 1}
# {'_id': 430, 'count_general_publicacions': 1}
# {'_id': 341, 'count_general_publicacions': 1}
# {'_id': 426, 'count_general_publicacions': 1}
# {'_id': 346, 'count_general_publicacions': 1}
# {'_id': 745, 'count_general_publicacions': 1}
# {'_id': 602, 'count_general_publicacions': 1}
# {'_id': 10, 'count_general_publicacions': 1}
# {'_id': 279, 'count_general_publicacions': 1}
# {'_id': 475, 'count_general_publicacions': 1}
# {'_id': 647, 'count_general_publicacions': 1}
# {'_id': 997, 'count_general_publicacions': 1}
# {'_id': 679, 'count_general_publicacions': 1}
# {'_id': 75, 'count_general_publicacions': 1}
# {'_id': 329, 'count_general_publicacions': 1}
# {'_id': 337, 'count_general_publicacions': 1}
# {'_id': 937, 'count_general_publicacions': 1}
# {'_id': 210, 'count_general_publicacions': 1}
# {'_id': 985, 'count_general_publicacions': 1}
# {'_id': 558, 'count_general_publicacions': 1}
# {'_id': 339, 'count_general_publicacions': 1}
# {'_id': 396, 'count_general_publicacions': 1}
# {'_id': 143, 'count_general_publicacions': 1}
# {'_id': 640, 'count_general_publicacions': 1}
# {'_id': 599, 'count_general_publicacions': 1}
# {'_id': 199, 'count_general_publicacions': 1}
# {'_id': 766, 'count_general_publicacions': 1}
# {'_id': 868, 'count_general_publicacions': 1}
# {'_id': 999, 'count_general_publicacions': 1}
# {'_id': 419, 'count_general_publicacions': 1}
# {'_id': 379, 'count_general_publicacions': 1}
# {'_id': 674, 'count_general_publicacions': 1}
# {'_id': 24, 'count_general_publicacions': 1}
# {'_id': 584, 'count_general_publicacions': 1}
# {'_id': 778, 'count_general_publicacions': 1}
# {'_id': 925, 'count_general_publicacions': 1}
# {'_id': 898, 'count_general_publicacions': 1}
# {'_id': 695, 'count_general_publicacions': 1}
# {'_id': 767, 'count_general_publicacions': 1}
# {'_id': 886, 'count_general_publicacions': 1}
# {'_id': 1, 'count_general_publicacions': 1}
# {'_id': 300, 'count_general_publicacions': 1}
# {'_id': 198, 'count_general_publicacions': 1}
# {'_id': 219, 'count_general_publicacions': 1}
# {'_id': 863, 'count_general_publicacions': 1}
# {'_id': 652, 'count_general_publicacions': 1}
# {'_id': 722, 'count_general_publicacions': 1}
# {'_id': 110, 'count_general_publicacions': 1}
# {'_id': 488, 'count_general_publicacions': 1}
# {'_id': 969, 'count_general_publicacions': 1}
# {'_id': 839, 'count_general_publicacions': 1}
# {'_id': 907, 'count_general_publicacions': 1}
# {'_id': 643, 'count_general_publicacions': 1}
# {'_id': 468, 'count_general_publicacions': 1}
# {'_id': 770, 'count_general_publicacions': 1}
# {'_id': 242, 'count_general_publicacions': 1}
# {'_id': 914, 'count_general_publicacions': 1}
# {'_id': 707, 'count_general_publicacions': 1}
# {'_id': 32, 'count_general_publicacions': 1}
# {'_id': 82, 'count_general_publicacions': 1}
# {'_id': 952, 'count_general_publicacions': 1}
# {'_id': 299, 'count_general_publicacions': 1}
# {'_id': 615, 'count_general_publicacions': 1}
# {'_id': 961, 'count_general_publicacions': 1}
# {'_id': 98, 'count_general_publicacions': 1}
# {'_id': 723, 'count_general_publicacions': 1}
# {'_id': 854, 'count_general_publicacions': 1}
# {'_id': 322, 'count_general_publicacions': 1}
# {'_id': 100, 'count_general_publicacions': 1}
# {'_id': 453, 'count_general_publicacions': 1}
# {'_id': 467, 'count_general_publicacions': 1}
# {'_id': 48, 'count_general_publicacions': 1}
# {'_id': 233, 'count_general_publicacions': 1}
# {'_id': 812, 'count_general_publicacions': 1}
# {'_id': 383, 'count_general_publicacions': 1}
# {'_id': 490, 'count_general_publicacions': 1}
# {'_id': 632, 'count_general_publicacions': 1}
# {'_id': 376, 'count_general_publicacions': 1}
# {'_id': 744, 'count_general_publicacions': 1}
# {'_id': 449, 'count_general_publicacions': 1}
# {'_id': 314, 'count_general_publicacions': 1}
# {'_id': 336, 'count_general_publicacions': 1}
# {'_id': 802, 'count_general_publicacions': 1}
# {'_id': 74, 'count_general_publicacions': 1}
# {'_id': 657, 'count_general_publicacions': 1}
# {'_id': 217, 'count_general_publicacions': 1}
# {'_id': 44, 'count_general_publicacions': 1}
# {'_id': 890, 'count_general_publicacions': 1}
# {'_id': 600, 'count_general_publicacions': 1}
# {'_id': 995, 'count_general_publicacions': 1}
# {'_id': 592, 'count_general_publicacions': 1}
# {'_id': 700, 'count_general_publicacions': 1}
# {'_id': 862, 'count_general_publicacions': 1}
# {'_id': 690, 'count_general_publicacions': 1}
# {'_id': 919, 'count_general_publicacions': 1}
# {'_id': 93, 'count_general_publicacions': 1}
# {'_id': 302, 'count_general_publicacions': 1}
# {'_id': 731, 'count_general_publicacions': 1}
# {'_id': 365, 'count_general_publicacions': 1}
# {'_id': 249, 'count_general_publicacions': 1}
# {'_id': 635, 'count_general_publicacions': 1}
# {'_id': 493, 'count_general_publicacions': 1}
# {'_id': 951, 'count_general_publicacions': 1}
# {'_id': 424, 'count_general_publicacions': 1}
# {'_id': 263, 'count_general_publicacions': 1}
# {'_id': 121, 'count_general_publicacions': 1}
# {'_id': 570, 'count_general_publicacions': 1}
# {'_id': 712, 'count_general_publicacions': 1}
# {'_id': 373, 'count_general_publicacions': 1}
# {'_id': 638, 'count_general_publicacions': 1}
# {'_id': 727, 'count_general_publicacions': 1}
# {'_id': 843, 'count_general_publicacions': 1}
# {'_id': 575, 'count_general_publicacions': 1}
# {'_id': 547, 'count_general_publicacions': 1}
# {'_id': 622, 'count_general_publicacions': 1}
# {'_id': 764, 'count_general_publicacions': 1}
# {'_id': 31, 'count_general_publicacions': 1}
# {'_id': 166, 'count_general_publicacions': 1}
# {'_id': 724, 'count_general_publicacions': 1}
# {'_id': 844, 'count_general_publicacions': 1}
# {'_id': 8, 'count_general_publicacions': 1}
# {'_id': 958, 'count_general_publicacions': 1}
# {'_id': 507, 'count_general_publicacions': 1}
# {'_id': 368, 'count_general_publicacions': 1}
# {'_id': 540, 'count_general_publicacions': 1}
# {'_id': 159, 'count_general_publicacions': 1}
# {'_id': 716, 'count_general_publicacions': 1}
# {'_id': 642, 'count_general_publicacions': 1}
# {'_id': 680, 'count_general_publicacions': 1}
# {'_id': 15, 'count_general_publicacions': 1}
# {'_id': 310, 'count_general_publicacions': 1}
# {'_id': 464, 'count_general_publicacions': 1}
# {'_id': 591, 'count_general_publicacions': 1}
# {'_id': 858, 'count_general_publicacions': 1}
# {'_id': 355, 'count_general_publicacions': 1}
# {'_id': 955, 'count_general_publicacions': 1}
# {'_id': 935, 'count_general_publicacions': 1}
# {'_id': 966, 'count_general_publicacions': 1}
# {'_id': 943, 'count_general_publicacions': 1}
# {'_id': 62, 'count_general_publicacions': 1}
# {'_id': 151, 'count_general_publicacions': 1}
# {'_id': 445, 'count_general_publicacions': 1}
# {'_id': 106, 'count_general_publicacions': 1}
# {'_id': 381, 'count_general_publicacions': 1}
# {'_id': 268, 'count_general_publicacions': 1}
# {'_id': 757, 'count_general_publicacions': 1}
# {'_id': 107, 'count_general_publicacions': 1}
# {'_id': 930, 'count_general_publicacions': 1}
# {'_id': 645, 'count_general_publicacions': 1}
# {'_id': 604, 'count_general_publicacions': 1}
# {'_id': 35, 'count_general_publicacions': 1}
# {'_id': 571, 'count_general_publicacions': 1}
# {'_id': 134, 'count_general_publicacions': 1}
# {'_id': 319, 'count_general_publicacions': 1}
# {'_id': 150, 'count_general_publicacions': 1}
# {'_id': 305, 'count_general_publicacions': 1}
# {'_id': 568, 'count_general_publicacions': 1}
# {'_id': 718, 'count_general_publicacions': 1}
# {'_id': 241, 'count_general_publicacions': 1}
# {'_id': 136, 'count_general_publicacions': 1}
# {'_id': 717, 'count_general_publicacions': 1}
# {'_id': 746, 'count_general_publicacions': 1}
# {'_id': 308, 'count_general_publicacions': 1}
# {'_id': 352, 'count_general_publicacions': 1}
# {'_id': 456, 'count_general_publicacions': 1}
# {'_id': 730, 'count_general_publicacions': 1}
# {'_id': 99, 'count_general_publicacions': 1}
# {'_id': 479, 'count_general_publicacions': 1}
# {'_id': 118, 'count_general_publicacions': 1}
# {'_id': 895, 'count_general_publicacions': 1}
# {'_id': 425, 'count_general_publicacions': 1}
# {'_id': 912, 'count_general_publicacions': 1}
# {'_id': 102, 'count_general_publicacions': 1}
# {'_id': 611, 'count_general_publicacions': 1}
# {'_id': 50, 'count_general_publicacions': 1}
# {'_id': 593, 'count_general_publicacions': 1}
# {'_id': 831, 'count_general_publicacions': 1}
# {'_id': 726, 'count_general_publicacions': 1}
# {'_id': 240, 'count_general_publicacions': 1}
# {'_id': 123, 'count_general_publicacions': 1}
# {'_id': 78, 'count_general_publicacions': 1}
# {'_id': 168, 'count_general_publicacions': 1}
# {'_id': 550, 'count_general_publicacions': 1}
# {'_id': 232, 'count_general_publicacions': 1}
# {'_id': 789, 'count_general_publicacions': 1}
# {'_id': 552, 'count_general_publicacions': 1}
# {'_id': 237, 'count_general_publicacions': 1}
# {'_id': 646, 'count_general_publicacions': 1}
# {'_id': 508, 'count_general_publicacions': 1}
# {'_id': 894, 'count_general_publicacions': 1}
# {'_id': 188, 'count_general_publicacions': 1}
# {'_id': 585, 'count_general_publicacions': 1}
# {'_id': 634, 'count_general_publicacions': 1}
# {'_id': 504, 'count_general_publicacions': 1}
# {'_id': 857, 'count_general_publicacions': 1}
# {'_id': 404, 'count_general_publicacions': 1}
# {'_id': 875, 'count_general_publicacions': 1}
# {'_id': 61, 'count_general_publicacions': 1}
# {'_id': 340, 'count_general_publicacions': 1}
# {'_id': 431, 'count_general_publicacions': 1}
# {'_id': 728, 'count_general_publicacions': 1}
# {'_id': 796, 'count_general_publicacions': 1}
# {'_id': 936, 'count_general_publicacions': 1}
# {'_id': 114, 'count_general_publicacions': 1}
# {'_id': 807, 'count_general_publicacions': 1}
# {'_id': 194, 'count_general_publicacions': 1}
# {'_id': 939, 'count_general_publicacions': 1}
# {'_id': 977, 'count_general_publicacions': 1}
# {'_id': 461, 'count_general_publicacions': 1}
# {'_id': 170, 'count_general_publicacions': 1}
# {'_id': 665, 'count_general_publicacions': 1}
# {'_id': 956, 'count_general_publicacions': 1}
# {'_id': 480, 'count_general_publicacions': 1}
# {'_id': 769, 'count_general_publicacions': 1}
# {'_id': 291, 'count_general_publicacions': 1}
# {'_id': 287, 'count_general_publicacions': 1}
# {'_id': 861, 'count_general_publicacions': 1}
# {'_id': 113, 'count_general_publicacions': 1}
# {'_id': 979, 'count_general_publicacions': 1}
# {'_id': 850, 'count_general_publicacions': 1}
# {'_id': 137, 'count_general_publicacions': 1}
# {'_id': 702, 'count_general_publicacions': 1}
# {'_id': 683, 'count_general_publicacions': 1}
# {'_id': 848, 'count_general_publicacions': 1}
# {'_id': 499, 'count_general_publicacions': 1}
# {'_id': 664, 'count_general_publicacions': 1}
# {'_id': 87, 'count_general_publicacions': 1}
# {'_id': 560, 'count_general_publicacions': 1}
# {'_id': 715, 'count_general_publicacions': 1}
# {'_id': 738, 'count_general_publicacions': 1}
# {'_id': 855, 'count_general_publicacions': 1}
# {'_id': 983, 'count_general_publicacions': 1}
# {'_id': 80, 'count_general_publicacions': 1}
# {'_id': 963, 'count_general_publicacions': 1}
# {'_id': 333, 'count_general_publicacions': 1}
# {'_id': 787, 'count_general_publicacions': 1}
# {'_id': 826, 'count_general_publicacions': 1}
# {'_id': 923, 'count_general_publicacions': 1}
# {'_id': 120, 'count_general_publicacions': 1}
# {'_id': 934, 'count_general_publicacions': 1}
# {'_id': 122, 'count_general_publicacions': 1}
# {'_id': 443, 'count_general_publicacions': 1}
# {'_id': 86, 'count_general_publicacions': 1}
# {'_id': 992, 'count_general_publicacions': 1}
# {'_id': 891, 'count_general_publicacions': 1}
# {'_id': 39, 'count_general_publicacions': 1}
# {'_id': 761, 'count_general_publicacions': 1}
# {'_id': 740, 'count_general_publicacions': 1}
# {'_id': 30, 'count_general_publicacions': 1}
# {'_id': 184, 'count_general_publicacions': 1}
# {'_id': 743, 'count_general_publicacions': 1}
# {'_id': 830, 'count_general_publicacions': 1}
# {'_id': 754, 'count_general_publicacions': 1}
# {'_id': 933, 'count_general_publicacions': 1}
# {'_id': 411, 'count_general_publicacions': 1}
# {'_id': 447, 'count_general_publicacions': 1}
# {'_id': 17, 'count_general_publicacions': 1}
# {'_id': 823, 'count_general_publicacions': 1}
# {'_id': 109, 'count_general_publicacions': 1}
# {'_id': 91, 'count_general_publicacions': 1}
# {'_id': 529, 'count_general_publicacions': 1}
# {'_id': 860, 'count_general_publicacions': 1}
# {'_id': 841, 'count_general_publicacions': 1}
# {'_id': 911, 'count_general_publicacions': 1}
# {'_id': 201, 'count_general_publicacions': 1}
# {'_id': 506, 'count_general_publicacions': 1}
# {'_id': 5, 'count_general_publicacions': 1}
# {'_id': 200, 'count_general_publicacions': 1}
# {'_id': 402, 'count_general_publicacions': 1}
# {'_id': 311, 'count_general_publicacions': 1}
# {'_id': 351, 'count_general_publicacions': 1}
# {'_id': 437, 'count_general_publicacions': 1}
# {'_id': 292, 'count_general_publicacions': 1}
# {'_id': 870, 'count_general_publicacions': 1}
# {'_id': 512, 'count_general_publicacions': 1}
# {'_id': 613, 'count_general_publicacions': 1}
# {'_id': 902, 'count_general_publicacions': 1}
# {'_id': 650, 'count_general_publicacions': 1}
# {'_id': 21, 'count_general_publicacions': 1}
# {'_id': 910, 'count_general_publicacions': 1}
# {'_id': 526, 'count_general_publicacions': 1}
# {'_id': 989, 'count_general_publicacions': 1}
# {'_id': 29, 'count_general_publicacions': 1}
# {'_id': 877, 'count_general_publicacions': 1}
# {'_id': 222, 'count_general_publicacions': 1}
# {'_id': 953, 'count_general_publicacions': 1}
# {'_id': 260, 'count_general_publicacions': 1}
# {'_id': 206, 'count_general_publicacions': 1}
# {'_id': 261, 'count_general_publicacions': 1}
# {'_id': 487, 'count_general_publicacions': 1}
# {'_id': 364, 'count_general_publicacions': 1}
# {'_id': 171, 'count_general_publicacions': 1}
# {'_id': 511, 'count_general_publicacions': 1}
# {'_id': 581, 'count_general_publicacions': 1}
# {'_id': 784, 'count_general_publicacions': 1}
# {'_id': 332, 'count_general_publicacions': 1}
# {'_id': 708, 'count_general_publicacions': 1}
# {'_id': 803, 'count_general_publicacions': 1}
# {'_id': 466, 'count_general_publicacions': 1}
# {'_id': 576, 'count_general_publicacions': 1}
# {'_id': 367, 'count_general_publicacions': 1}
# {'_id': 538, 'count_general_publicacions': 1}
# {'_id': 115, 'count_general_publicacions': 1}
# {'_id': 790, 'count_general_publicacions': 1}
# {'_id': 940, 'count_general_publicacions': 1}
# {'_id': 327, 'count_general_publicacions': 1}
# {'_id': 892, 'count_general_publicacions': 1}
# {'_id': 542, 'count_general_publicacions': 1}
# {'_id': 633, 'count_general_publicacions': 1}
# {'_id': 132, 'count_general_publicacions': 1}
# {'_id': 97, 'count_general_publicacions': 1}
# {'_id': 223, 'count_general_publicacions': 1}
# {'_id': 375, 'count_general_publicacions': 1}
# {'_id': 653, 'count_general_publicacions': 1}
# {'_id': 124, 'count_general_publicacions': 1}
# {'_id': 413, 'count_general_publicacions': 1}
# {'_id': 51, 'count_general_publicacions': 1}
# {'_id': 471, 'count_general_publicacions': 1}
# {'_id': 873, 'count_general_publicacions': 1}
# {'_id': 204, 'count_general_publicacions': 1}
# {'_id': 574, 'count_general_publicacions': 1}
# {'_id': 639, 'count_general_publicacions': 1}
# {'_id': 392, 'count_general_publicacions': 1}
# {'_id': 735, 'count_general_publicacions': 1}
# {'_id': 781, 'count_general_publicacions': 1}
# {'_id': 968, 'count_general_publicacions': 1}
# {'_id': 616, 'count_general_publicacions': 1}
# {'_id': 725, 'count_general_publicacions': 1}
# {'_id': 422, 'count_general_publicacions': 1}
# {'_id': 594, 'count_general_publicacions': 1}
# {'_id': 450, 'count_general_publicacions': 1}
# {'_id': 931, 'count_general_publicacions': 1}
# {'_id': 165, 'count_general_publicacions': 1}
# {'_id': 513, 'count_general_publicacions': 1}
# {'_id': 625, 'count_general_publicacions': 1}
# {'_id': 156, 'count_general_publicacions': 1}
# {'_id': 889, 'count_general_publicacions': 1}
# {'_id': 244, 'count_general_publicacions': 1}
# {'_id': 852, 'count_general_publicacions': 1}
# {'_id': 55, 'count_general_publicacions': 1}
# {'_id': 83, 'count_general_publicacions': 1}
# {'_id': 309, 'count_general_publicacions': 1}
# {'_id': 973, 'count_general_publicacions': 1}
# {'_id': 409, 'count_general_publicacions': 1}
# {'_id': 234, 'count_general_publicacions': 1}
# {'_id': 297, 'count_general_publicacions': 1}
# {'_id': 444, 'count_general_publicacions': 1}
# {'_id': 944, 'count_general_publicacions': 1}
# {'_id': 172, 'count_general_publicacions': 1}
# {'_id': 614, 'count_general_publicacions': 1}
# {'_id': 817, 'count_general_publicacions': 1}
# {'_id': 822, 'count_general_publicacions': 1}
# {'_id': 866, 'count_general_publicacions': 1}
# {'_id': 524, 'count_general_publicacions': 1}
# {'_id': 865, 'count_general_publicacions': 1}
# {'_id': 438, 'count_general_publicacions': 1}
# {'_id': 783, 'count_general_publicacions': 1}
# {'_id': 366, 'count_general_publicacions': 1}
# {'_id': 605, 'count_general_publicacions': 1}
# {'_id': 965, 'count_general_publicacions': 1}
# {'_id': 12, 'count_general_publicacions': 1}
# {'_id': 358, 'count_general_publicacions': 1}
# {'_id': 503, 'count_general_publicacions': 1}
# {'_id': 544, 'count_general_publicacions': 1}
# {'_id': 589, 'count_general_publicacions': 1}
# {'_id': 896, 'count_general_publicacions': 1}
# {'_id': 929, 'count_general_publicacions': 1}
# {'_id': 298, 'count_general_publicacions': 1}
# {'_id': 533, 'count_general_publicacions': 1}
# {'_id': 38, 'count_general_publicacions': 1}
# {'_id': 360, 'count_general_publicacions': 1}
# {'_id': 920, 'count_general_publicacions': 1}
# {'_id': 916, 'count_general_publicacions': 1}
# {'_id': 52, 'count_general_publicacions': 1}
# {'_id': 749, 'count_general_publicacions': 1}
# {'_id': 648, 'count_general_publicacions': 1}
# {'_id': 837, 'count_general_publicacions': 1}
# {'_id': 177, 'count_general_publicacions': 1}
# {'_id': 651, 'count_general_publicacions': 1}
# {'_id': 250, 'count_general_publicacions': 1}
# {'_id': 543, 'count_general_publicacions': 1}
# {'_id': 286, 'count_general_publicacions': 1}
# {'_id': 548, 'count_general_publicacions': 1}
# {'_id': 805, 'count_general_publicacions': 1}
# {'_id': 970, 'count_general_publicacions': 1}
# {'_id': 932, 'count_general_publicacions': 1}
# {'_id': 125, 'count_general_publicacions': 1}
# {'_id': 49, 'count_general_publicacions': 1}
# {'_id': 403, 'count_general_publicacions': 1}
# {'_id': 913, 'count_general_publicacions': 1}
# {'_id': 116, 'count_general_publicacions': 1}
# {'_id': 775, 'count_general_publicacions': 1}
# {'_id': 909, 'count_general_publicacions': 1}
# {'_id': 1000, 'count_general_publicacions': 1}
# {'_id': 606, 'count_general_publicacions': 1}
# {'_id': 864, 'count_general_publicacions': 1}
# {'_id': 293, 'count_general_publicacions': 1}
# {'_id': 788, 'count_general_publicacions': 1}
# {'_id': 510, 'count_general_publicacions': 1}
# {'_id': 221, 'count_general_publicacions': 1}
# {'_id': 390, 'count_general_publicacions': 1}
# {'_id': 288, 'count_general_publicacions': 1}
# {'_id': 518, 'count_general_publicacions': 1}
# {'_id': 149, 'count_general_publicacions': 1}
# {'_id': 256, 'count_general_publicacions': 1}
# {'_id': 698, 'count_general_publicacions': 1}
# {'_id': 660, 'count_general_publicacions': 1}
# {'_id': 138, 'count_general_publicacions': 1}
# {'_id': 243, 'count_general_publicacions': 1}
# {'_id': 883, 'count_general_publicacions': 1}
# {'_id': 195, 'count_general_publicacions': 1}
# {'_id': 617, 'count_general_publicacions': 1}
# {'_id': 227, 'count_general_publicacions': 1}
# {'_id': 711, 'count_general_publicacions': 1}
# {'_id': 583, 'count_general_publicacions': 1}
# {'_id': 954, 'count_general_publicacions': 1}
# {'_id': 362, 'count_general_publicacions': 1}
# {'_id': 155, 'count_general_publicacions': 1}
# {'_id': 842, 'count_general_publicacions': 1}
# {'_id': 703, 'count_general_publicacions': 1}
# {'_id': 734, 'count_general_publicacions': 1}
# {'_id': 421, 'count_general_publicacions': 1}
# {'_id': 528, 'count_general_publicacions': 1}
# {'_id': 46, 'count_general_publicacions': 1}
# {'_id': 262, 'count_general_publicacions': 1}
# {'_id': 463, 'count_general_publicacions': 1}
# {'_id': 825, 'count_general_publicacions': 1}
# {'_id': 58, 'count_general_publicacions': 1}
# {'_id': 693, 'count_general_publicacions': 1}
# {'_id': 69, 'count_general_publicacions': 1}
# {'_id': 25, 'count_general_publicacions': 1}
# {'_id': 736, 'count_general_publicacions': 1}
# {'_id': 212, 'count_general_publicacions': 1}
# {'_id': 183, 'count_general_publicacions': 1}
# {'_id': 141, 'count_general_publicacions': 1}
# {'_id': 962, 'count_general_publicacions': 1}
# {'_id': 186, 'count_general_publicacions': 1}
# {'_id': 231, 'count_general_publicacions': 1}
# {'_id': 344, 'count_general_publicacions': 1}
# {'_id': 454, 'count_general_publicacions': 1}
# {'_id': 72, 'count_general_publicacions': 1}
# {'_id': 505, 'count_general_publicacions': 1}
# {'_id': 273, 'count_general_publicacions': 1}
# {'_id': 290, 'count_general_publicacions': 1}
# {'_id': 301, 'count_general_publicacions': 1}
# {'_id': 881, 'count_general_publicacions': 1}
# {'_id': 921, 'count_general_publicacions': 1}
# {'_id': 126, 'count_general_publicacions': 1}
# {'_id': 820, 'count_general_publicacions': 1}
# {'_id': 536, 'count_general_publicacions': 1}
# {'_id': 582, 'count_general_publicacions': 1}
# {'_id': 462, 'count_general_publicacions': 1}
# {'_id': 320, 'count_general_publicacions': 1}
# {'_id': 688, 'count_general_publicacions': 1}
# {'_id': 272, 'count_general_publicacions': 1}
# {'_id': 153, 'count_general_publicacions': 1}
# {'_id': 283, 'count_general_publicacions': 1}
# {'_id': 631, 'count_general_publicacions': 1}
# {'_id': 175, 'count_general_publicacions': 1}
# {'_id': 519, 'count_general_publicacions': 1}
# {'_id': 441, 'count_general_publicacions': 1}
# {'_id': 945, 'count_general_publicacions': 1}
# {'_id': 474, 'count_general_publicacions': 1}
# {'_id': 460, 'count_general_publicacions': 1}
# {'_id': 483, 'count_general_publicacions': 1}
# {'_id': 13, 'count_general_publicacions': 1}
# {'_id': 847, 'count_general_publicacions': 1}
# {'_id': 998, 'count_general_publicacions': 1}
# {'_id': 4, 'count_general_publicacions': 1}
# {'_id': 938, 'count_general_publicacions': 1}
# {'_id': 71, 'count_general_publicacions': 1}
# {'_id': 167, 'count_general_publicacions': 1}
# {'_id': 23, 'count_general_publicacions': 1}
# {'_id': 391, 'count_general_publicacions': 1}
# {'_id': 22, 'count_general_publicacions': 1}
# {'_id': 457, 'count_general_publicacions': 1}
# {'_id': 140, 'count_general_publicacions': 1}
# {'_id': 975, 'count_general_publicacions': 1}
# {'_id': 991, 'count_general_publicacions': 1}
# {'_id': 68, 'count_general_publicacions': 1}
# {'_id': 33, 'count_general_publicacions': 1}
# {'_id': 917, 'count_general_publicacions': 1}
# {'_id': 810, 'count_general_publicacions': 1}
# {'_id': 162, 'count_general_publicacions': 1}
# {'_id': 369, 'count_general_publicacions': 1}
# {'_id': 851, 'count_general_publicacions': 1}
# {'_id': 872, 'count_general_publicacions': 1}
# {'_id': 809, 'count_general_publicacions': 1}
# {'_id': 709, 'count_general_publicacions': 1}
# {'_id': 266, 'count_general_publicacions': 1}
# {'_id': 791, 'count_general_publicacions': 1}
# {'_id': 239, 'count_general_publicacions': 1}
# {'_id': 590, 'count_general_publicacions': 1}
# {'_id': 92, 'count_general_publicacions': 1}
# {'_id': 996, 'count_general_publicacions': 1}
# {'_id': 331, 'count_general_publicacions': 1}
# {'_id': 880, 'count_general_publicacions': 1}
# {'_id': 34, 'count_general_publicacions': 1}
# {'_id': 54, 'count_general_publicacions': 1}
# {'_id': 641, 'count_general_publicacions': 1}
# {'_id': 792, 'count_general_publicacions': 1}
# {'_id': 555, 'count_general_publicacions': 1}
# {'_id': 442, 'count_general_publicacions': 1}
# {'_id': 644, 'count_general_publicacions': 1}
# {'_id': 959, 'count_general_publicacions': 1}
# {'_id': 90, 'count_general_publicacions': 1}
# {'_id': 313, 'count_general_publicacions': 1}
# {'_id': 515, 'count_general_publicacions': 1}
# {'_id': 799, 'count_general_publicacions': 1}
# {'_id': 173, 'count_general_publicacions': 1}
# {'_id': 572, 'count_general_publicacions': 1}
# {'_id': 70, 'count_general_publicacions': 1}
# {'_id': 942, 'count_general_publicacions': 1}
# {'_id': 428, 'count_general_publicacions': 1}
# {'_id': 213, 'count_general_publicacions': 1}
# {'_id': 531, 'count_general_publicacions': 1}
# {'_id': 277, 'count_general_publicacions': 1}
# {'_id': 296, 'count_general_publicacions': 1}
# {'_id': 620, 'count_general_publicacions': 1}
# {'_id': 384, 'count_general_publicacions': 1}
# {'_id': 779, 'count_general_publicacions': 1}
# {'_id': 684, 'count_general_publicacions': 1}
# {'_id': 429, 'count_general_publicacions': 1}
# {'_id': 202, 'count_general_publicacions': 1}
# {'_id': 372, 'count_general_publicacions': 1}
# {'_id': 215, 'count_general_publicacions': 1}
# {'_id': 105, 'count_general_publicacions': 1}
# {'_id': 777, 'count_general_publicacions': 1}
# {'_id': 253, 'count_general_publicacions': 1}
# {'_id': 458, 'count_general_publicacions': 1}
# {'_id': 427, 'count_general_publicacions': 1}
# {'_id': 246, 'count_general_publicacions': 1}
# {'_id': 500, 'count_general_publicacions': 1}
# {'_id': 407, 'count_general_publicacions': 1}
# {'_id': 380, 'count_general_publicacions': 1}
# {'_id': 335, 'count_general_publicacions': 1}
# {'_id': 687, 'count_general_publicacions': 1}
# {'_id': 755, 'count_general_publicacions': 1}
# {'_id': 659, 'count_general_publicacions': 1}
# {'_id': 89, 'count_general_publicacions': 1}
# {'_id': 117, 'count_general_publicacions': 1}
# {'_id': 972, 'count_general_publicacions': 1}
# {'_id': 824, 'count_general_publicacions': 1}
# {'_id': 876, 'count_general_publicacions': 1}
# {'_id': 706, 'count_general_publicacions': 1}
# {'_id': 800, 'count_general_publicacions': 1}
# {'_id': 949, 'count_general_publicacions': 1}
# {'_id': 378, 'count_general_publicacions': 1}
# {'_id': 813, 'count_general_publicacions': 1}
# {'_id': 578, 'count_general_publicacions': 1}
# {'_id': 990, 'count_general_publicacions': 1}
# {'_id': 111, 'count_general_publicacions': 1}
# {'_id': 901, 'count_general_publicacions': 1}
# {'_id': 73, 'count_general_publicacions': 1}
# {'_id': 906, 'count_general_publicacions': 1}
# {'_id': 878, 'count_general_publicacions': 1}
# {'_id': 897, 'count_general_publicacions': 1}
# {'_id': 801, 'count_general_publicacions': 1}
# {'_id': 347, 'count_general_publicacions': 1}
# {'_id': 491, 'count_general_publicacions': 1}
# {'_id': 405, 'count_general_publicacions': 1}
# {'_id': 472, 'count_general_publicacions': 1}
# {'_id': 926, 'count_general_publicacions': 1}
# {'_id': 941, 'count_general_publicacions': 1}
# {'_id': 696, 'count_general_publicacions': 1}
# {'_id': 417, 'count_general_publicacions': 1}
# {'_id': 129, 'count_general_publicacions': 1}
# {'_id': 624, 'count_general_publicacions': 1}
# {'_id': 394, 'count_general_publicacions': 1}
# {'_id': 957, 'count_general_publicacions': 1}
# {'_id': 495, 'count_general_publicacions': 1}
# {'_id': 16, 'count_general_publicacions': 1}
# {'_id': 294, 'count_general_publicacions': 1}
# {'_id': 808, 'count_general_publicacions': 1}
# {'_id': 964, 'count_general_publicacions': 1}
# {'_id': 597, 'count_general_publicacions': 1}
# {'_id': 974, 'count_general_publicacions': 1}
# {'_id': 551, 'count_general_publicacions': 1}
# {'_id': 478, 'count_general_publicacions': 1}
# {'_id': 836, 'count_general_publicacions': 1}
# {'_id': 410, 'count_general_publicacions': 1}
# {'_id': 840, 'count_general_publicacions': 1}
# {'_id': 435, 'count_general_publicacions': 1}
# {'_id': 523, 'count_general_publicacions': 1}
# {'_id': 619, 'count_general_publicacions': 1}
# {'_id': 53, 'count_general_publicacions': 1}
# {'_id': 264, 'count_general_publicacions': 1}
# {'_id': 408, 'count_general_publicacions': 1}
# {'_id': 815, 'count_general_publicacions': 1}
# {'_id': 330, 'count_general_publicacions': 1}
# {'_id': 893, 'count_general_publicacions': 1}
# {'_id': 245, 'count_general_publicacions': 1}
# {'_id': 77, 'count_general_publicacions': 1}
# {'_id': 993, 'count_general_publicacions': 1}
# {'_id': 465, 'count_general_publicacions': 1}
# {'_id': 732, 'count_general_publicacions': 1}
# {'_id': 520, 'count_general_publicacions': 1}
# {'_id': 382, 'count_general_publicacions': 1}
# {'_id': 556, 'count_general_publicacions': 1}
# {'_id': 663, 'count_general_publicacions': 1}
# {'_id': 395, 'count_general_publicacions': 1}
# {'_id': 780, 'count_general_publicacions': 1}
# {'_id': 6, 'count_general_publicacions': 1}
# {'_id': 94, 'count_general_publicacions': 1}
# {'_id': 685, 'count_general_publicacions': 1}
# {'_id': 41, 'count_general_publicacions': 1}
# {'_id': 169, 'count_general_publicacions': 1}
# {'_id': 385, 'count_general_publicacions': 1}
# {'_id': 252, 'count_general_publicacions': 1}
# {'_id': 981, 'count_general_publicacions': 1}
# {'_id': 27, 'count_general_publicacions': 1}
# {'_id': 182, 'count_general_publicacions': 1}
# {'_id': 762, 'count_general_publicacions': 1}
# {'_id': 400, 'count_general_publicacions': 1}
# {'_id': 668, 'count_general_publicacions': 1}
# {'_id': 811, 'count_general_publicacions': 1}
# {'_id': 670, 'count_general_publicacions': 1}
# {'_id': 315, 'count_general_publicacions': 1}
# {'_id': 181, 'count_general_publicacions': 1}
# {'_id': 104, 'count_general_publicacions': 1}
# {'_id': 573, 'count_general_publicacions': 1}
# {'_id': 514, 'count_general_publicacions': 1}
# {'_id': 733, 'count_general_publicacions': 1}
# {'_id': 317, 'count_general_publicacions': 1}
# {'_id': 345, 'count_general_publicacions': 1}
# {'_id': 502, 'count_general_publicacions': 1}
# {'_id': 627, 'count_general_publicacions': 1}
# {'_id': 276, 'count_general_publicacions': 1}
# {'_id': 178, 'count_general_publicacions': 1}
# {'_id': 275, 'count_general_publicacions': 1}
# {'_id': 418, 'count_general_publicacions': 1}
# {'_id': 36, 'count_general_publicacions': 1}
# {'_id': 133, 'count_general_publicacions': 1}
# {'_id': 887, 'count_general_publicacions': 1}
# {'_id': 610, 'count_general_publicacions': 1}
# {'_id': 658, 'count_general_publicacions': 1}
# {'_id': 476, 'count_general_publicacions': 1}
# {'_id': 397, 'count_general_publicacions': 1}
# {'_id': 608, 'count_general_publicacions': 1}
# {'_id': 596, 'count_general_publicacions': 1}
# {'_id': 666, 'count_general_publicacions': 1}
# {'_id': 255, 'count_general_publicacions': 1}
# {'_id': 112, 'count_general_publicacions': 1}
# {'_id': 328, 'count_general_publicacions': 1}
# {'_id': 623, 'count_general_publicacions': 1}
# {'_id': 393, 'count_general_publicacions': 1}
# {'_id': 656, 'count_general_publicacions': 1}
# {'_id': 667, 'count_general_publicacions': 1}
# {'_id': 577, 'count_general_publicacions': 1}
# {'_id': 609, 'count_general_publicacions': 1}
# {'_id': 485, 'count_general_publicacions': 1}
# {'_id': 759, 'count_general_publicacions': 1}
# {'_id': 794, 'count_general_publicacions': 1}
# {'_id': 67, 'count_general_publicacions': 1}
# {'_id': 452, 'count_general_publicacions': 1}
# {'_id': 247, 'count_general_publicacions': 1}
# {'_id': 433, 'count_general_publicacions': 1}
# {'_id': 713, 'count_general_publicacions': 1}
# {'_id': 763, 'count_general_publicacions': 1}
# {'_id': 701, 'count_general_publicacions': 1}
# {'_id': 673, 'count_general_publicacions': 1}
# {'_id': 741, 'count_general_publicacions': 1}
# {'_id': 103, 'count_general_publicacions': 1}
# {'_id': 37, 'count_general_publicacions': 1}
# {'_id': 587, 'count_general_publicacions': 1}
# {'_id': 562, 'count_general_publicacions': 1}
# {'_id': 924, 'count_general_publicacions': 1}
# {'_id': 535, 'count_general_publicacions': 1}
# {'_id': 142, 'count_general_publicacions': 1}
# {'_id': 776, 'count_general_publicacions': 1}
# {'_id': 721, 'count_general_publicacions': 1}
# {'_id': 451, 'count_general_publicacions': 1}
# {'_id': 230, 'count_general_publicacions': 1}
# {'_id': 530, 'count_general_publicacions': 1}
# {'_id': 190, 'count_general_publicacions': 1}
# {'_id': 534, 'count_general_publicacions': 1}
# {'_id': 566, 'count_general_publicacions': 1}
# {'_id': 401, 'count_general_publicacions': 1}
# {'_id': 494, 'count_general_publicacions': 1}
# {'_id': 976, 'count_general_publicacions': 1}
# {'_id': 161, 'count_general_publicacions': 1}
# {'_id': 564, 'count_general_publicacions': 1}
# {'_id': 773, 'count_general_publicacions': 1}
# {'_id': 675, 'count_general_publicacions': 1}
# {'_id': 295, 'count_general_publicacions': 1}
# {'_id': 918, 'count_general_publicacions': 1}
# {'_id': 359, 'count_general_publicacions': 1}
# {'_id': 527, 'count_general_publicacions': 1}
# {'_id': 786, 'count_general_publicacions': 1}
# {'_id': 835, 'count_general_publicacions': 1}
# {'_id': 742, 'count_general_publicacions': 1}
# {'_id': 978, 'count_general_publicacions': 1}
# {'_id': 205, 'count_general_publicacions': 1}
# {'_id': 699, 'count_general_publicacions': 1}
# {'_id': 579, 'count_general_publicacions': 1}
# {'_id': 154, 'count_general_publicacions': 1}
# {'_id': 3, 'count_general_publicacions': 1}
# {'_id': 135, 'count_general_publicacions': 1}
# {'_id': 59, 'count_general_publicacions': 1}
# {'_id': 128, 'count_general_publicacions': 1}
# {'_id': 752, 'count_general_publicacions': 1}
# {'_id': 908, 'count_general_publicacions': 1}
# {'_id': 324, 'count_general_publicacions': 1}
# {'_id': 612, 'count_general_publicacions': 1}
# {'_id': 446, 'count_general_publicacions': 1}
# {'_id': 904, 'count_general_publicacions': 1}
# {'_id': 720, 'count_general_publicacions': 1}
# {'_id': 224, 'count_general_publicacions': 1}
# {'_id': 374, 'count_general_publicacions': 1}
# {'_id': 950, 'count_general_publicacions': 1}
# {'_id': 254, 'count_general_publicacions': 1}
# {'_id': 64, 'count_general_publicacions': 1}
# {'_id': 307, 'count_general_publicacions': 1}
# {'_id': 846, 'count_general_publicacions': 1}
# {'_id': 988, 'count_general_publicacions': 1}
# {'_id': 57, 'count_general_publicacions': 1}
# {'_id': 714, 'count_general_publicacions': 1}
# {'_id': 869, 'count_general_publicacions': 1}
# {'_id': 163, 'count_general_publicacions': 1}
# {'_id': 806, 'count_general_publicacions': 1}
# {'_id': 833, 'count_general_publicacions': 1}
# {'_id': 131, 'count_general_publicacions': 1}
# {'_id': 2, 'count_general_publicacions': 1}
# {'_id': 259, 'count_general_publicacions': 1}
# {'_id': 271, 'count_general_publicacions': 1}
# {'_id': 629, 'count_general_publicacions': 1}
# {'_id': 356, 'count_general_publicacions': 1}
# {'_id': 598, 'count_general_publicacions': 1}
# {'_id': 66, 'count_general_publicacions': 1}
# {'_id': 40, 'count_general_publicacions': 1}
# {'_id': 96, 'count_general_publicacions': 1}
# {'_id': 192, 'count_general_publicacions': 1}
# {'_id': 56, 'count_general_publicacions': 1}
# {'_id': 484, 'count_general_publicacions': 1}
# {'_id': 119, 'count_general_publicacions': 1}
# {'_id': 522, 'count_general_publicacions': 1}
# {'_id': 900, 'count_general_publicacions': 1}
# {'_id': 152, 'count_general_publicacions': 1}
# {'_id': 455, 'count_general_publicacions': 1}
# {'_id': 209, 'count_general_publicacions': 1}
# {'_id': 546, 'count_general_publicacions': 1}
# {'_id': 681, 'count_general_publicacions': 1}
# {'_id': 386, 'count_general_publicacions': 1}
# {'_id': 179, 'count_general_publicacions': 1}
# {'_id': 326, 'count_general_publicacions': 1}
# {'_id': 278, 'count_general_publicacions': 1}
# {'_id': 459, 'count_general_publicacions': 1}
# {'_id': 971, 'count_general_publicacions': 1}
# {'_id': 828, 'count_general_publicacions': 1}
# {'_id': 316, 'count_general_publicacions': 1}

# %%
# Institución y cantidad de publicaciones

stage_group_institution_number_publications = {
  "$group": {
    "_id" : "$institucion_id.institucion_nombre",
    "count_publicaciones_x_institucion": {"$sum": 1}
  }
}

stage_out_institution_number_publications = {
  "$out": "out_num_publicaciones_x_institucion"
}

pipeline = [
  stage_group_institution_number_publications,
  stage_out_institution_number_publications
]

results = publicaciones.aggregate(pipeline)

for publications_by_intitutions_mapreduce in mdb["out_num_publicaciones_x_institucion"].find():
  print(publications_by_intitutions_mapreduce)
# Out:
# {'_id': None, 'count_publicaciones_x_institucion': 1000}

# %%
# Publicaciones por Sede

stage_group_publication_by_sede = {
  "$group": {
    "_id" : "$egresado_id.sede_nombre",
    "count_publications_by_sedes": {"$sum": 1} #count_publicaciones_x_institucion
  }
}

stage_out_publications_by_sede = {
  "$out": "out_num_publications_by_sede" # out_num_publicaciones_x_institucion
}

pipeline = [
  stage_group_publication_by_sede,
  stage_out_publications_by_sede
]

#results = publicaciones.aggregate(pipeline)
results = publicaciones.aggregate(pipeline)


for public_mapreduce in mdb["out_num_publications_by_sede"].find():
  print(public_mapreduce)
# Out:
# {'_id': None, 'count_publications_by_sedes': 1000}

# %%
# Publicaciones por año

stage_group_year = {
  "$group": {
    "_id" : {"$year": {"$toDate": "$date_id"}},
    "count_publications_by_year": {"$sum": 1} # count_publications_by_year
  }
}

stage_out_year = {
  "$out": "out_num_publications_by_year" # out_num_publications_by_year
}

pipeline = [
  stage_group_year,
  stage_out_year
]

results = publicaciones.aggregate(pipeline)

for graduacion_mapreduce in mdb["out_num_publications_by_year"].find():
  print(graduacion_mapreduce)
# Out:
# {'_id': None, 'count_publications_by_year': 1000}
