# %% [markdown]
# # MapReduce Publicaciones

# %%
###############################################################
#!/usr/bin/python
# Purpose: Migrate Products from MySQL to Mongo
# Dependecies : python-pip , pymongo , mysqldb
# apt-get install python-pip ; pip install pymongo;
# apt-get install python-MySQLdb


import pymongo
import datetime
import enum
from pprint import pprint

# %%
########################################################################################
mongodb_host            = 'mongodb://localhost:27017'
mongodb_dbname          = 'migrate_bda'
n_collection            = 'publicaciones'
#########################
mclient = pymongo.MongoClient(mongodb_host)
mdb = mclient[mongodb_dbname]

# %%
collections = mdb.list_collection_names()
print(collections)
# Out:
# ['graduaciones', 'publicaciones', 'out_num_publicaciones_x_institucion', 'out_num_general_publications']

# %%
publicaciones = mdb["publicaciones"]
pprint(publicaciones.find()[0])
# Out:
# {'_id': ObjectId('662355df7b6690d646518e76'),
#  'date_id': '1994-10-01',
#  'egresado_id': {'egresado_id': 60, 'sede_nombre': 'ORINOQUIA'},
#  'institucion_id': None,
#  'publicacion_id': {'ano_publiacion': '1994-10-01',
#                     'descripcion': 'Investment specific general thousand child '
#                                    'hundred group only. Certainly wrong trip '
#                                    'forward college. Different couple door '
#                                    'total yeah it break remember. Within poor '
#                                    'care interview describe.',
#                     'publicacion_id': 489,
#                     'tipo_publicacion': 'Recently.'},
#  'registration_id': 1,
#  'revista_id': {'revista_id': 1342, 'revista_nombre': 'Attention.'}}

# %%
# Tipo de Publicaciones General

stage_group_general_publications = {
  "$group": {
    "_id" : "$publicacion_id",
    "count_general_publicacions": {"$sum": 1}
  }
}

stage_out_general_publications = {
  "$out": "out_num_general_publications"
}

pipeline = [
  stage_group_general_publications,
  stage_out_general_publications
]

results = publicaciones.aggregate(pipeline)

for publicaciones_mapreduce in mdb["out_num_general_publications"].find():
  print(publicaciones_mapreduce)
# Out:
# {'_id': {'publicacion_id': 978, 'tipo_publicacion': 'Director.', 'ano_publiacion': '2007-08-06', 'descripcion': 'Shake act the position beat. Produce civil since dog goal skill side. Fill after participant brother catch carry statement red. If unit window note phone.'}, 'count_general_publicacions': 14}
# {'_id': {'publicacion_id': 44, 'tipo_publicacion': 'Know put.', 'ano_publiacion': '1992-04-08', 'descripcion': 'Even nearly magazine new sit pressure suffer. Eye whose interest man best. Heart hear body everybody expert husband. Marriage base expert enter. Technology toward federal floor one bag.'}, 'count_general_publicacions': 12}
# {'_id': {'publicacion_id': 800, 'tipo_publicacion': 'Better.', 'ano_publiacion': '1975-05-22', 'descripcion': 'Mention fire probably. Today then value idea. Among seven against different medical international seem. Thank table suffer surface special share peace. Treatment oil family.'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 660, 'tipo_publicacion': 'Family.', 'ano_publiacion': '2007-03-26', 'descripcion': 'Both strategy tough maintain. Style early kitchen they which Mr fly. Cup main cost when prevent.'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 606, 'tipo_publicacion': 'Himself.', 'ano_publiacion': '2010-12-11', 'descripcion': 'Image only avoid choice surface. Even PM contain he. Record save leg skill since. Draw make property professor represent job lot read. Man although this nice drive remain new. Will carry rate.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 40, 'tipo_publicacion': 'Group.', 'ano_publiacion': '1989-10-28', 'descripcion': 'Choose rock support after already discussion. Painting same what according. Drop wonder west bill walk. Art long call better peace help any back. Follow than create lose assume life about recognize. F'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 930, 'tipo_publicacion': 'Form fear.', 'ano_publiacion': '1982-06-24', 'descripcion': 'Mr return military option direction store court. Age work arrive authority could. Agency item current require. All yard agency arrive both. Culture when appear detail set. These age for concern whole '}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 235, 'tipo_publicacion': 'Can.', 'ano_publiacion': '2023-08-09', 'descripcion': 'Address hotel maintain while page. Success blue newspaper personal minute. Focus board science. Mother TV mind.'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 283, 'tipo_publicacion': 'Upon.', 'ano_publiacion': '2002-10-28', 'descripcion': 'Federal style board. Rest writer whole nearly star though state. However city image nice fund. Environment wonder set agree. Address teach care reveal measure land.'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 815, 'tipo_publicacion': 'Firm.', 'ano_publiacion': '2010-01-24', 'descripcion': 'Make think structure pass citizen. Ten even future might their want level. Significant everyone cultural necessary. West game bring moment. Early bring system book. Pressure ok type I.'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 588, 'tipo_publicacion': 'Approach.', 'ano_publiacion': '1976-01-04', 'descripcion': 'From image have sing. Develop room crime wall. New town she. Rock both begin to certain loss.'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 846, 'tipo_publicacion': 'Speak.', 'ano_publiacion': '1972-09-21', 'descripcion': 'Join trip might material particularly wide future. Morning school lay. Region above million game. Whose task book about chance between.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 42, 'tipo_publicacion': 'Exist.', 'ano_publiacion': '1984-09-02', 'descripcion': 'Put growth staff. Themselves machine law mean cause. Hope number manager son local take. Rest near green keep face them. Economic bar everything someone offer media unit.'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 382, 'tipo_publicacion': 'Amount.', 'ano_publiacion': '1974-10-13', 'descripcion': 'Chance huge hundred candidate full. Film lead what happy hit off. Always actually option will hour.'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 212, 'tipo_publicacion': 'Enough.', 'ano_publiacion': '1999-07-08', 'descripcion': 'Fight friend turn account room eye yes space. Weight cut floor none food husband. May new card protect rather. Option soldier method pressure give. Green return just oil nothing must concern professor'}, 'count_general_publicacions': 7}
# {'_id': {'publicacion_id': 928, 'tipo_publicacion': 'Sometimes.', 'ano_publiacion': '2021-02-11', 'descripcion': 'Idea social national water movie. My thousand forget mother yet particular. World go policy walk. Road culture physical democratic must radio include. Contain though society serve medical former weigh'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 848, 'tipo_publicacion': 'With walk.', 'ano_publiacion': '1993-02-12', 'descripcion': 'Everyone space message answer hit. Use claim future friend. However drug catch place. Sometimes knowledge fear professor.'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 54, 'tipo_publicacion': 'Drive.', 'ano_publiacion': '2014-12-16', 'descripcion': 'Front cost protect generation themselves. Question such we good food per direction. Position then score history experience into adult. Onto forward approach drug wrong. Part young bill recently. Bed s'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 534, 'tipo_publicacion': 'Sister.', 'ano_publiacion': '2008-05-12', 'descripcion': 'Program wall country quite boy miss. West respond real message would matter. General drug color. Teach fire number either face public product.'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 756, 'tipo_publicacion': 'Tell show.', 'ano_publiacion': '1974-11-30', 'descripcion': 'Practice reveal respond attack company individual. Dark whom develop process position amount. True remain give account less. Everyone charge join out camera. Hold evening art road hundred quickly. Wel'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 555, 'tipo_publicacion': 'Miss.', 'ano_publiacion': '1972-06-16', 'descripcion': 'Important actually over notice everything. Leave house source movie. Theory anything kitchen believe. Think authority check record.'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 489, 'tipo_publicacion': 'Recently.', 'ano_publiacion': '1994-10-01', 'descripcion': 'Investment specific general thousand child hundred group only. Certainly wrong trip forward college. Different couple door total yeah it break remember. Within poor care interview describe.'}, 'count_general_publicacions': 8}
# {'_id': {'publicacion_id': 51, 'tipo_publicacion': 'Listen.', 'ano_publiacion': '1975-10-12', 'descripcion': 'Place present bed key program pretty. Forward education in behavior manage attention. Fly military us professor certain fire. Leg blood way sure. Language production policy never.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 625, 'tipo_publicacion': 'Maybe.', 'ano_publiacion': '1997-06-03', 'descripcion': 'None piece perhaps opportunity new with play professional. Memory compare recognize stock instead forget will. Term situation analysis.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 839, 'tipo_publicacion': 'Compare.', 'ano_publiacion': '1995-12-14', 'descripcion': 'Throw role quickly where. Operation food a add laugh no main. Friend pay then let to. Contain would run production specific whose skin. Natural within collection from stock worker author. Degree yours'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 535, 'tipo_publicacion': 'Blood.', 'ano_publiacion': '2006-09-27', 'descripcion': 'Present probably I already blood certainly compare rock. Care man fire interview customer account common. Girl market yard business mother particular.'}, 'count_general_publicacions': 12}
# {'_id': {'publicacion_id': 640, 'tipo_publicacion': 'In argue.', 'ano_publiacion': '2009-07-19', 'descripcion': 'Arrive real exist. Site challenge black hard everybody low. Century various avoid start wall performance.'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 678, 'tipo_publicacion': 'Certain.', 'ano_publiacion': '2003-02-08', 'descripcion': 'Director stand trip media away finish those field. Population bit full. Since same issue as control. Team heavy success stay personal return. Near send art standard.'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 232, 'tipo_publicacion': 'Group.', 'ano_publiacion': '2009-09-09', 'descripcion': 'Once return care fact risk. Large four south plant result interesting. Politics friend fast local everybody walk wish. They message article huge firm beyond. Fish phone short cut material role. Sound '}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 258, 'tipo_publicacion': 'Identify.', 'ano_publiacion': '2012-11-21', 'descripcion': 'Go wife tax Mr. Pretty social live under argue forget table. Activity attorney purpose state wind. Attack any edge someone.'}, 'count_general_publicacions': 7}
# {'_id': {'publicacion_id': 466, 'tipo_publicacion': 'Old.', 'ano_publiacion': '1992-12-11', 'descripcion': 'Office while him would. Cause candidate outside move. With science from run. Little wish issue charge.'}, 'count_general_publicacions': 1}
# {'_id': {'publicacion_id': 218, 'tipo_publicacion': 'Travel.', 'ano_publiacion': '1999-09-01', 'descripcion': 'Defense close line. Close customer others scene follow three operation. Campaign good institution ten note best.'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 183, 'tipo_publicacion': 'Music.', 'ano_publiacion': '1998-04-07', 'descripcion': 'Few provide member already majority. Control suggest reason. Have help nothing guy current. Mind baby enjoy artist myself. Computer particularly station force.'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 367, 'tipo_publicacion': 'Somebody.', 'ano_publiacion': '1984-05-18', 'descripcion': 'Various carry large usually. Generation about ok work hear. Else important indeed child nice vote. Might road power song.'}, 'count_general_publicacions': 21}
# {'_id': {'publicacion_id': 19, 'tipo_publicacion': 'Shake.', 'ano_publiacion': '1994-08-27', 'descripcion': 'Rest three magazine individual. Though along try election game direction. Few dinner all home change key begin.'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 66, 'tipo_publicacion': 'Adult.', 'ano_publiacion': '2023-07-10', 'descripcion': 'Theory usually bring let require me technology during. Design six support exactly. Order pay resource trip action.'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 91, 'tipo_publicacion': 'Minute.', 'ano_publiacion': '2017-08-10', 'descripcion': 'Fly population book none a analysis. Hope government safe though weight. Wish answer case. Parent bed much maintain treat. Also right I car participant.'}, 'count_general_publicacions': 9}
# {'_id': {'publicacion_id': 419, 'tipo_publicacion': 'Church.', 'ano_publiacion': '1983-01-24', 'descripcion': 'Weight voice contain through interview leader baby. Claim education else. Agree like stage. Close most return white. Help support foot fill quality hold live. Thus image by get majority.'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 798, 'tipo_publicacion': 'Begin.', 'ano_publiacion': '1987-02-20', 'descripcion': 'Who speech significant go always say food pull. Their pretty claim ask change new course. Suggest share thus data political per.'}, 'count_general_publicacions': 8}
# {'_id': {'publicacion_id': 74, 'tipo_publicacion': 'According.', 'ano_publiacion': '1970-02-27', 'descripcion': 'Try interview realize assume future lawyer politics chair. Deep look add those hear require build. Without rule gas sell.'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 788, 'tipo_publicacion': 'Beautiful.', 'ano_publiacion': '1971-12-30', 'descripcion': 'It two during truth stock. Nor make history. Practice reflect fly tell. Community military government simply green goal. Loss force camera.'}, 'count_general_publicacions': 1}
# {'_id': {'publicacion_id': 447, 'tipo_publicacion': 'Notice.', 'ano_publiacion': '1991-05-28', 'descripcion': 'North dinner listen her trial item significant. Bring police born use cause. Evening I including now also. Large use customer his main. Business second information.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 754, 'tipo_publicacion': 'Loss sing.', 'ano_publiacion': '1993-08-14', 'descripcion': 'Chair street contain its sound available. None continue evening table art. Police boy new past people study say speech. Now would respond modern college fear.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 830, 'tipo_publicacion': 'May order.', 'ano_publiacion': '1980-06-25', 'descripcion': 'While reason teacher coach cut single attention expect. Trade situation many development employee. Let special opportunity item stuff decade. Air TV final man rather hold save serious.'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 72, 'tipo_publicacion': 'Strong.', 'ano_publiacion': '1979-02-19', 'descripcion': 'Eye seat school Democrat. Again boy design shake man. Stay statement claim anything great experience reach.'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 495, 'tipo_publicacion': 'Debate.', 'ano_publiacion': '1985-05-11', 'descripcion': 'Marriage century laugh people. View prove carry. Better development strong. Go cultural difficult fire from place onto thousand. Television even he economy reach best worker. Change today four still.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 565, 'tipo_publicacion': 'Guess by.', 'ano_publiacion': '2003-01-27', 'descripcion': 'Available just reduce now develop father. Character almost outside only evidence never. Position throw your. Which military common bed. Maybe every culture school. Along people experience spring bill '}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 242, 'tipo_publicacion': 'Office.', 'ano_publiacion': '2007-07-21', 'descripcion': 'Decision difference star response sea or. Between read significant very itself sit cost. Six carry exactly forget everybody possible agent. Black huge into bad yet. Say most trouble rich maybe blood m'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 300, 'tipo_publicacion': 'Truth.', 'ano_publiacion': '2017-02-20', 'descripcion': 'Study as bit professional. Book point sell drop weight. Recognize teach whatever live whole when. Top second nor practice bank add image.'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 792, 'tipo_publicacion': 'Room why.', 'ano_publiacion': '1998-12-20', 'descripcion': 'Well say her report analysis pick. Imagine ask fall may nice industry you. Six direction organization. Time summer station dog.'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 231, 'tipo_publicacion': 'Star.', 'ano_publiacion': '1993-09-03', 'descripcion': 'Different wait term happy card. Professor visit audience ready beat star. Employee seat particular science form court fall close. Reduce political piece recent someone include. Person suffer level man'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 440, 'tipo_publicacion': 'Attack.', 'ano_publiacion': '2023-04-17', 'descripcion': 'Campaign affect water activity if. Camera deal nothing deal. Nothing fill student best hotel growth. Property part visit continue onto nearly. Always strategy growth through skin skill return. Suggest'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 852, 'tipo_publicacion': 'Suffer.', 'ano_publiacion': '1978-10-22', 'descripcion': 'Security feel care continue dream. During institution discuss seat. Debate exist ability get gun return. Nothing with general none human production.'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 581, 'tipo_publicacion': 'Back.', 'ano_publiacion': '1983-11-09', 'descripcion': 'Budget small beat common member free. Road nor service sign call. His team card discover him us religious. Democrat now trial. Debate result society.'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 814, 'tipo_publicacion': 'Agree.', 'ano_publiacion': '2014-04-05', 'descripcion': 'Management structure very seek investment either. Clearly know significant serious learn alone. Where interview her human. Anything story fall service rule. Figure perhaps buy clearly item him.'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 662, 'tipo_publicacion': 'Four area.', 'ano_publiacion': '1975-07-25', 'descripcion': 'Evidence religious weight some. His land order situation sport thousand. Friend loss like mention. Feel great yes listen lawyer.'}, 'count_general_publicacions': 1}
# {'_id': {'publicacion_id': 110, 'tipo_publicacion': 'Health.', 'ano_publiacion': '1988-06-24', 'descripcion': 'Social security production check according. As foreign response apply raise. Fall party audience four senior.'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 127, 'tipo_publicacion': 'Office.', 'ano_publiacion': '2000-04-01', 'descripcion': 'Throw represent ever measure possible popular friend. Necessary take science assume cold artist. Pattern enjoy say against they agree sea. Field little drug network discussion performance leader. Righ'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 510, 'tipo_publicacion': 'Power.', 'ano_publiacion': '2023-07-25', 'descripcion': 'Fill value feeling she. Audience check since trial. Expect whatever big tend. Image many less society of herself treatment. Simple management floor add.'}, 'count_general_publicacions': 1}
# {'_id': {'publicacion_id': 507, 'tipo_publicacion': 'Town.', 'ano_publiacion': '1987-01-06', 'descripcion': 'Ability fill staff against adult. Increase yeah say. Brother sign man power.'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 459, 'tipo_publicacion': 'Figure.', 'ano_publiacion': '1981-01-28', 'descripcion': 'Enter fear organization develop. Speak science middle prove series compare threat. Foot line class father window its responsibility. Mrs you pick collection reveal. Environment civil plant whole pass '}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 273, 'tipo_publicacion': 'Market.', 'ano_publiacion': '1989-10-08', 'descripcion': 'Sort expert project however campaign. Listen until bill generation thought less particularly. Market perhaps body east artist before off. Their lot month employee charge.'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 659, 'tipo_publicacion': 'Form cold.', 'ano_publiacion': '2001-03-16', 'descripcion': 'Western range project meeting number house occur. Left individual food walk hold throughout. Million word at world newspaper style others. Artist build in front.'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 431, 'tipo_publicacion': 'Buy ok.', 'ano_publiacion': '1975-07-30', 'descripcion': 'Good people difficult image kid music its. Mrs performance writer hair. Film change want necessary vote season. Once base do baby. Continue no benefit their often Democrat sense.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 799, 'tipo_publicacion': 'Drug plan.', 'ano_publiacion': '1977-04-06', 'descripcion': 'Throw develop interest member crime. Again star hope occur. Mean cold street firm side.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 134, 'tipo_publicacion': 'Myself.', 'ano_publiacion': '1988-04-18', 'descripcion': 'Act news resource charge doctor news positive. Itself buy truth. Green white adult join education third kitchen. Oil story knowledge seem. Under table value thousand start every. Year laugh sea manage'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 289, 'tipo_publicacion': 'Hospital.', 'ano_publiacion': '2014-07-27', 'descripcion': 'Hope arm should discover property floor phone. Benefit only blue realize. According carry analysis could. Indeed democratic on old better. Change western become interest call relationship.'}, 'count_general_publicacions': 1}
# {'_id': {'publicacion_id': 395, 'tipo_publicacion': 'Science.', 'ano_publiacion': '1996-03-12', 'descripcion': 'Standard human fish worker baby high. Skin both population bit real sometimes. Sound yard firm sure. Financial author story wish artist here likely. Expert ten no arrive peace above available.'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 96, 'tipo_publicacion': 'Action.', 'ano_publiacion': '2016-06-12', 'descripcion': 'Hospital article involve with laugh he. Into yourself summer government owner. At travel best resource list method less. Space reduce imagine. Budget near market prove. Town drop mouth learn relate sm'}, 'count_general_publicacions': 1}
# {'_id': {'publicacion_id': 373, 'tipo_publicacion': 'When.', 'ano_publiacion': '1979-08-12', 'descripcion': 'Allow important same right notice program environment. Nor land sign behavior accept kitchen head edge. Upon director foot himself least pretty young. Compare democratic condition parent me.'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 239, 'tipo_publicacion': 'Energy.', 'ano_publiacion': '2000-08-28', 'descripcion': 'Over five soldier. Run set ball figure character. Heavy continue hope take now message. Despite population Congress think likely ago. Increase present talk ok into red appear summer.'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 313, 'tipo_publicacion': 'Stock.', 'ano_publiacion': '2015-03-11', 'descripcion': 'Personal goal myself important know. No front every. Report old shake behavior drug employee. Suffer value onto treat sing region.'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 302, 'tipo_publicacion': 'Piece.', 'ano_publiacion': '2000-08-20', 'descripcion': 'Star claim everybody long unit support. Interesting window hold surface message less discuss. Section enjoy enter statement.'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 925, 'tipo_publicacion': 'Culture.', 'ano_publiacion': '2001-08-10', 'descripcion': 'Director although all space necessary back. Republican idea not reality national. Rather about small section animal. Senior attack key matter say value trial. Perform road realize enough line simple.'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 552, 'tipo_publicacion': 'Democrat.', 'ano_publiacion': '2020-08-03', 'descripcion': 'Specific experience similar. Series company woman bill. Method public Democrat summer lead job event. Production south add threat.'}, 'count_general_publicacions': 8}
# {'_id': {'publicacion_id': 542, 'tipo_publicacion': 'Wish deep.', 'ano_publiacion': '2015-11-27', 'descripcion': 'No stay executive perhaps reflect blue site. Scientist rich past where want. Option total staff lead article his amount.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 75, 'tipo_publicacion': 'Plan.', 'ano_publiacion': '2012-05-08', 'descripcion': 'Soon shake hope hair necessary audience high. My short difference task care treatment. Water close rule eat blue new. Others follow voice leader fall rock.'}, 'count_general_publicacions': 16}
# {'_id': {'publicacion_id': 148, 'tipo_publicacion': 'Quite.', 'ano_publiacion': '1997-11-27', 'descripcion': 'First computer outside us imagine another. Respond Congress prepare five sound. Already soldier event short word century.'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 708, 'tipo_publicacion': 'Alone.', 'ano_publiacion': '1997-12-18', 'descripcion': 'Reveal set level answer education. Over high experience establish. Full mean analysis throw wind sense. Range individual manager well soldier true policy.'}, 'count_general_publicacions': 7}
# {'_id': {'publicacion_id': 904, 'tipo_publicacion': 'Everybody.', 'ano_publiacion': '1995-04-04', 'descripcion': 'Loss evidence approach. Wrong contain within throw. Real recognize bank tend these deep. Gun allow leg.'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 611, 'tipo_publicacion': 'Say that.', 'ano_publiacion': '2017-12-16', 'descripcion': 'Organization book experience car modern grow manager. Outside hour table style. Security turn recent. Discover return guess buy. Million sea wide fund allow or interview. Best this sense career ago ne'}, 'count_general_publicacions': 8}
# {'_id': {'publicacion_id': 260, 'tipo_publicacion': 'Find word.', 'ano_publiacion': '1970-05-13', 'descripcion': 'Too magazine above. Early administration unit offer anyone artist a. One should item local option. Environment his job campaign cell establish.'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 842, 'tipo_publicacion': 'Democrat.', 'ano_publiacion': '2018-04-06', 'descripcion': 'Speak for fear film claim news manage entire. Work manager surface. Quickly message it role wind arrive single. Risk question street wrong city even alone others. Become city before billion reality.'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 622, 'tipo_publicacion': 'Today.', 'ano_publiacion': '2022-11-07', 'descripcion': 'Become hot hard today. Health social too no. Read spend instead senior easy.'}, 'count_general_publicacions': 1}
# {'_id': {'publicacion_id': 933, 'tipo_publicacion': 'Nearly.', 'ano_publiacion': '1974-03-31', 'descripcion': 'Off others American just beautiful computer. Believe win charge drive. Bed job sort sound movie fish front.'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 991, 'tipo_publicacion': 'Now then.', 'ano_publiacion': '2002-02-07', 'descripcion': 'International anything hair ever seem free. Child treatment both any. Remain along example would maintain best. Animal step brother later. Despite officer close hold world and international. Suggest b'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 61, 'tipo_publicacion': 'Nation.', 'ano_publiacion': '2005-01-07', 'descripcion': 'Program organization model garden half particularly. Admit model professional fact administration available site. Building executive child similar lead president. Off manager fight employee be. Season'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 321, 'tipo_publicacion': 'Ready.', 'ano_publiacion': '1977-08-26', 'descripcion': 'Against dog finish organization just. Medical everybody these money example must east. Likely local trouble rich book ability very. Key sister even example stuff next. Many better girl officer profess'}, 'count_general_publicacions': 16}
# {'_id': {'publicacion_id': 813, 'tipo_publicacion': 'Some.', 'ano_publiacion': '2019-05-31', 'descripcion': 'Other represent song success skin officer really. Action share government. Exist important travel himself situation. Start beat PM why her society during yourself.'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 655, 'tipo_publicacion': 'Billion.', 'ano_publiacion': '2021-10-07', 'descripcion': 'A reason blue hope speech international. Marriage cup study fall yet go. Run list huge threat common two wish first. Should computer hold wind director yes. College meeting talk late product across ma'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 676, 'tipo_publicacion': 'Court.', 'ano_publiacion': '2009-06-06', 'descripcion': 'Table bring meet whole once public candidate. Both necessary yourself political. People direction well mouth.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 626, 'tipo_publicacion': 'General.', 'ano_publiacion': '1990-05-23', 'descripcion': 'Walk financial claim might spring. Thank will local even. Upon democratic door fast involve understand. Do degree outside appear improve unit. Inside during cold letter which million.'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 529, 'tipo_publicacion': 'See door.', 'ano_publiacion': '2022-02-09', 'descripcion': 'Response thank head send candidate read natural. Marriage term trip me. Audience not anything after. Page edge yet I toward compare. Recent view property Mrs condition mind.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 178, 'tipo_publicacion': 'Mention.', 'ano_publiacion': '1971-12-29', 'descripcion': 'Bad look whole leg kid high activity. Change college win energy serious hundred still. Government budget which key rock such reflect.'}, 'count_general_publicacions': 12}
# {'_id': {'publicacion_id': 3, 'tipo_publicacion': 'For.', 'ano_publiacion': '2007-01-27', 'descripcion': 'Couple eye receive school decision least pull. Certainly should eat cold space cut collection color. Enter process girl sit window. Hair position vote turn region institution hot name.'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 776, 'tipo_publicacion': 'From.', 'ano_publiacion': '2008-02-13', 'descripcion': 'Cost garden least name star. Attorney none member away night reality particular door. Business wall check. Herself at western likely. Accept either south project drop. Computer clear total.'}, 'count_general_publicacions': 1}
# {'_id': {'publicacion_id': 578, 'tipo_publicacion': 'Politics.', 'ano_publiacion': '2008-01-12', 'descripcion': 'Case teacher image data raise leader often. Whom record west work discuss teach. Entire firm physical enjoy interview peace should. Continue positive figure little. Prepare street cold every create. W'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 500, 'tipo_publicacion': 'Morning.', 'ano_publiacion': '1993-07-12', 'descripcion': 'Much chance once big. Themselves next region. Walk machine main another find. None main particularly marriage interview race human.'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 932, 'tipo_publicacion': 'Perform.', 'ano_publiacion': '2003-04-21', 'descripcion': 'Analysis join state course left someone effort. Above drop agree. Return behind operation middle method.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 647, 'tipo_publicacion': 'Owner.', 'ano_publiacion': '2001-12-12', 'descripcion': 'Sort room middle evening. Actually surface record country. Figure next direction indicate increase add single. Eye certain population. Inside personal million address much lay. Wind within require mor'}, 'count_general_publicacions': 7}
# {'_id': {'publicacion_id': 2, 'tipo_publicacion': 'Bad story.', 'ano_publiacion': '2023-01-26', 'descripcion': 'Provide prepare nothing approach may. Nation soldier reach series scene natural. After while use final theory particular. Media whatever minute actually name.'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 184, 'tipo_publicacion': 'Increase.', 'ano_publiacion': '2021-10-01', 'descripcion': 'Class laugh grow. Weight from these receive we risk leg. Anyone production possible leave west must interview.'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 82, 'tipo_publicacion': 'Represent.', 'ano_publiacion': '1977-08-26', 'descripcion': 'Yet contain friend hundred training eat number. Inside social north possible. Fight dog research under fast. Every research let face hear project. Project old agree very full. Loss market husband rest'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 833, 'tipo_publicacion': 'Summer no.', 'ano_publiacion': '1981-05-13', 'descripcion': 'My mouth spring particular sense. Possible usually serious never social war. Finish ahead traditional. Door design like we read kitchen. Pattern thousand can whatever say according star.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 757, 'tipo_publicacion': 'Most data.', 'ano_publiacion': '2021-09-14', 'descripcion': 'Difficult commercial network here the choice. Ready old leader author. Forget dog record pick. Off on reach reason pull audience. Behavior might pass her bar food yes.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 338, 'tipo_publicacion': 'Study.', 'ano_publiacion': '2006-03-05', 'descripcion': 'Middle media TV dog final during author. Painting open personal certainly most when scene wind. Away resource hair idea.'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 668, 'tipo_publicacion': 'Care.', 'ano_publiacion': '2005-12-27', 'descripcion': 'Help report brother. Opportunity appear by value sign participant. Forget Republican responsibility through. Decision citizen her partner present current student. Four few why grow what scene. Tend fo'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 608, 'tipo_publicacion': 'Arrive.', 'ano_publiacion': '2010-03-18', 'descripcion': 'Story class short house rest. Law almost body suggest. Culture executive brother. Draw also good song husband exist himself. Interest check vote rise firm include general quite.'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 969, 'tipo_publicacion': 'Behind.', 'ano_publiacion': '1976-10-12', 'descripcion': 'According yourself color. Go hospital he window pay together. Per product unit participant. Term two box cold some its.'}, 'count_general_publicacions': 8}
# {'_id': {'publicacion_id': 294, 'tipo_publicacion': 'Age.', 'ano_publiacion': '1975-12-18', 'descripcion': 'Born begin movie window onto talk. Political take accept improve stock itself economy. Visit against risk class just. Can cultural stay fall rate energy political research.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 116, 'tipo_publicacion': 'Because.', 'ano_publiacion': '1988-06-01', 'descripcion': 'Modern article front back doctor room. There almost stuff unit hundred. Hair feeling interest very product hot top. Write future high mind upon another. Mr so anything law job far carry.'}, 'count_general_publicacions': 1}
# {'_id': {'publicacion_id': 666, 'tipo_publicacion': 'Watch.', 'ano_publiacion': '2017-10-07', 'descripcion': 'Also magazine month amount. Tax deal bit little wide threat. Degree less treatment else around customer. Two cell performance stay medical process build television. Still color arrive peace century.'}, 'count_general_publicacions': 12}
# {'_id': {'publicacion_id': 931, 'tipo_publicacion': 'What.', 'ano_publiacion': '1977-09-15', 'descripcion': 'Figure be trade bank interest example entire. Professor accept sort this real before. Music none son side rich. Shake at leave yeah less. Life interview light million ever heavy. Or bed nothing big wi'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 152, 'tipo_publicacion': 'College.', 'ano_publiacion': '2012-07-08', 'descripcion': 'Wish man contain operation stuff too maintain. Government than by add well read. Face stock strong common. Authority according couple prevent. Without enter order step we meeting customer.'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 553, 'tipo_publicacion': 'Movement.', 'ano_publiacion': '1998-07-26', 'descripcion': 'New several Republican minute. Young by family environmental why book down. Market as sea require really.'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 67, 'tipo_publicacion': 'Quickly.', 'ano_publiacion': '1997-02-12', 'descripcion': 'Power receive her unit usually gun use. Modern movement base upon tell almost run behavior. Board reduce conference area. Go question guess member stay see four. Hot evidence general consumer.'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 267, 'tipo_publicacion': 'Prove.', 'ano_publiacion': '1999-04-12', 'descripcion': 'Analysis spend drive director much about question. Kid physical car rock one. Imagine fire ever image program development deal. Present foreign happen president. Trial talk discussion.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 557, 'tipo_publicacion': 'Increase.', 'ano_publiacion': '1978-02-05', 'descripcion': 'Usually customer build friend she. Bank site eat natural debate least trial. Talk off other staff. Parent yeah too manage type forward.'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 977, 'tipo_publicacion': 'Mission.', 'ano_publiacion': '1989-08-20', 'descripcion': 'Building kitchen seat our behind. Boy age movie those. If think government thought. Include can responsibility account data machine nature. Hundred small ball experience else where street.'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 115, 'tipo_publicacion': 'Human.', 'ano_publiacion': '2023-01-01', 'descripcion': 'Describe American economic laugh church kitchen prepare. Sell crime yourself we door year somebody. Front environmental letter give position especially.'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 591, 'tipo_publicacion': 'Military.', 'ano_publiacion': '1980-02-16', 'descripcion': 'Game fish major move table. Daughter middle no kid policy. Born able another natural early live consumer. Us hear old so senior always us. Bed during record sign organization teach.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 896, 'tipo_publicacion': 'Like now.', 'ano_publiacion': '2006-01-04', 'descripcion': 'Medical always toward own rate south institution table. Realize pattern dark which in. Left attack machine will heavy might beautiful. Allow effort question federal. Lead appear administration evening'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 726, 'tipo_publicacion': 'Serious.', 'ano_publiacion': '1989-07-26', 'descripcion': 'Everything investment daughter quite describe range. Improve suffer sign catch. Nice individual join likely war then.'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 882, 'tipo_publicacion': 'Magazine.', 'ano_publiacion': '2003-06-08', 'descripcion': 'Near himself later after feeling listen local. Always affect chance inside fight. By name buy feeling head. Place military seem sound.'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 569, 'tipo_publicacion': 'Imagine.', 'ano_publiacion': '1984-07-06', 'descripcion': 'Talk mission run hundred technology. Party ball fire control cup wait. Fine through hand relationship catch however lay.'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 497, 'tipo_publicacion': 'Security.', 'ano_publiacion': '1977-07-19', 'descripcion': 'Share could later. Political expect apply though measure suffer traditional. Allow option usually between. Type officer these some current.'}, 'count_general_publicacions': 16}
# {'_id': {'publicacion_id': 980, 'tipo_publicacion': 'Life.', 'ano_publiacion': '2005-09-30', 'descripcion': 'Visit water attention finish environment public. Everybody keep interest. Try study top rich nice lose son. Tree expert role student too. Compare these crime information case yard. Cold reduce war car'}, 'count_general_publicacions': 7}
# {'_id': {'publicacion_id': 598, 'tipo_publicacion': 'Newspaper.', 'ano_publiacion': '2019-04-03', 'descripcion': 'Add produce but house wonder guy. Short fill above firm exactly but. Student wait analysis even often each. Fact culture anyone one tree beat. Stay their Mr watch. Black ago find call throw law wait.'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 653, 'tipo_publicacion': 'Him.', 'ano_publiacion': '1985-02-02', 'descripcion': 'Authority buy cost interview deal. Performance off mention fund major certainly. Spring offer doctor we far center. Which billion develop traditional west. His these get few. Expect pressure middle de'}, 'count_general_publicacions': 10}
# {'_id': {'publicacion_id': 285, 'tipo_publicacion': 'Face.', 'ano_publiacion': '1999-08-18', 'descripcion': 'By care certain director sport write skill. Election together answer say. Purpose point throughout population scene.'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 120, 'tipo_publicacion': 'Society.', 'ano_publiacion': '1984-01-20', 'descripcion': 'State history mean. Though bring father far. Country activity stop industry music yard try. Result capital few lawyer institution experience. Growth reflect finish authority fire. Win should staff.'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 828, 'tipo_publicacion': 'Maintain.', 'ano_publiacion': '2021-05-15', 'descripcion': 'Of clear other even. Party support political mouth or maybe. Painting believe guy section adult Mr.'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 406, 'tipo_publicacion': 'High.', 'ano_publiacion': '2013-10-07', 'descripcion': 'Partner draw experience. Number mind thought. Another list accept medical throughout line.'}, 'count_general_publicacions': 8}
# {'_id': {'publicacion_id': 633, 'tipo_publicacion': 'See must.', 'ano_publiacion': '2014-10-28', 'descripcion': 'Of look green think eight culture toward. Others nation develop certainly goal social foot. Affect someone gun state young. Throw newspaper argue enter.'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 483, 'tipo_publicacion': 'City.', 'ano_publiacion': '2001-05-03', 'descripcion': 'Opportunity no catch argue perform college factor. Necessary now fight point site. Try record few house policy air.'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 403, 'tipo_publicacion': 'Five.', 'ano_publiacion': '2009-08-07', 'descripcion': 'Usually space federal live. Sort laugh best loss its lose field. Act night easy boy partner throughout relationship. Where increase fund investment character. Focus however table option.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 28, 'tipo_publicacion': 'Election.', 'ano_publiacion': '1982-08-18', 'descripcion': 'Evening quite several woman same usually weight. Pull day keep start network environmental may. Few value door nice fact themselves lead benefit. Stay only part major this. Body middle small region he'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 236, 'tipo_publicacion': 'Agency.', 'ano_publiacion': '1990-02-21', 'descripcion': 'Happen table tonight individual agent development. Fire leader by center threat school new. Economic list song meet at book. Consumer tend popular line other. Interest system very.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 661, 'tipo_publicacion': 'Improve.', 'ano_publiacion': '1972-10-12', 'descripcion': 'Anyone red person group view expert. Must along candidate party notice house. Night middle everybody. College character financial speech since school.'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 204, 'tipo_publicacion': 'Life.', 'ano_publiacion': '1974-04-30', 'descripcion': 'Song such door model. Call second news list significant site seven. Drop race free traditional already head.'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 770, 'tipo_publicacion': 'Force.', 'ano_publiacion': '2005-04-12', 'descripcion': 'Mention collection or and production protect view. Government return style inside worker sell find. Ago film her guess easy something. Lead future military example effort message federal.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 413, 'tipo_publicacion': 'Election.', 'ano_publiacion': '1980-11-04', 'descripcion': 'Democratic after look. Probably trade new. Into difficult seven to pretty size page option. Door positive vote. Season meet practice show a. Same first teach watch set agency.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 101, 'tipo_publicacion': 'Expert.', 'ano_publiacion': '1978-01-18', 'descripcion': 'Lot indeed sort religious perform event. Board trade on Democrat become American great. Participant growth respond nation. Everybody plant together also loss plant save. Wife beautiful understand sort'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 763, 'tipo_publicacion': 'Sort.', 'ano_publiacion': '1980-07-18', 'descripcion': 'For guy approach floor detail. Population industry because wall political. Push enough almost oil.'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 895, 'tipo_publicacion': 'Low.', 'ano_publiacion': '1980-05-20', 'descripcion': 'Someone remember decide threat. Play life structure people. Power describe none hotel manage letter short. Loss nor scene series. Miss where particular light be. Difficult stock particularly success t'}, 'count_general_publicacions': 7}
# {'_id': {'publicacion_id': 131, 'tipo_publicacion': 'Expert.', 'ano_publiacion': '2016-10-06', 'descripcion': 'Have medical us since including tough. Among score clear. Arrive water fine fight way before anyone. Story office learn figure report against always our. Number low huge begin we. Be sister special sp'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 306, 'tipo_publicacion': 'Green.', 'ano_publiacion': '1988-10-04', 'descripcion': 'Stay choose source left. Recognize imagine heart college assume network. Less charge behind technology.'}, 'count_general_publicacions': 8}
# {'_id': {'publicacion_id': 712, 'tipo_publicacion': 'Every.', 'ano_publiacion': '2001-11-07', 'descripcion': 'Plant model indeed others loss interesting wife. Rate yet national close appear fly site. Employee there clearly report main security take task. Remember price in threat. Benefit share somebody down r'}, 'count_general_publicacions': 9}
# {'_id': {'publicacion_id': 16, 'tipo_publicacion': 'For later.', 'ano_publiacion': '1997-06-19', 'descripcion': 'Heart because write health. Say mean I now. Watch we personal laugh. Strong surface hotel take. Player method past director feel democratic practice foreign.'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 893, 'tipo_publicacion': 'Soon.', 'ano_publiacion': '1986-09-16', 'descripcion': 'Town better network agent nor whether see. Course fish onto treatment dog TV. Congress goal prepare TV bill someone represent. Whose hospital hundred catch second if tough. Audience message cut tough '}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 543, 'tipo_publicacion': 'Take.', 'ano_publiacion': '2007-12-14', 'descripcion': 'Middle guess show wife decision prevent management. Employee will four force price. Until heavy several million reach.'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 765, 'tipo_publicacion': 'Sense.', 'ano_publiacion': '2019-01-03', 'descripcion': 'Place behind her perform church single office. Could increase seem deal. Certainly break lot act wait.'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 132, 'tipo_publicacion': 'Return.', 'ano_publiacion': '2015-07-04', 'descripcion': 'Set receive visit time they. Protect class remain house machine magazine. Nothing this organization word. Only term section two part.'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 541, 'tipo_publicacion': 'Bag next.', 'ano_publiacion': '2013-05-05', 'descripcion': 'Around cell what scientist day walk save. Bed attack must turn young. Lawyer agency wind teach information build process simply.'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 24, 'tipo_publicacion': 'Ability.', 'ano_publiacion': '2015-11-26', 'descripcion': 'Environment structure stay wonder every. Side down religious front church soldier. Address front business of foreign call. Talk task raise religious.'}, 'count_general_publicacions': 1}
# {'_id': {'publicacion_id': 216, 'tipo_publicacion': 'Pattern.', 'ano_publiacion': '2017-02-14', 'descripcion': 'Mouth beat boy certain. Cut wrong Mrs miss and live actually provide. On rock respond eat or ago.'}, 'count_general_publicacions': 4}
# ...
# {'_id': {'publicacion_id': 818, 'tipo_publicacion': 'Wall him.', 'ano_publiacion': '1982-02-02', 'descripcion': 'Mean build face. First another wall knowledge yard hold kid. Notice huge student Republican citizen represent. Blue spend significant education without. Population tell about between address thought w'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 962, 'tipo_publicacion': 'Keep.', 'ano_publiacion': '2011-08-09', 'descripcion': 'Play stop ever single challenge life. Record possible season economic. Brother discover peace form rich. Star once individual answer everything friend data. Everybody suggest read position become conf'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 721, 'tipo_publicacion': 'Issue air.', 'ano_publiacion': '2005-04-26', 'descripcion': 'Green close form foreign. Challenge scientist husband play including always data. Pressure follow may high she watch gun. Ability season since road. Perform best already. Trial throughout walk lawyer '}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 405, 'tipo_publicacion': 'Close.', 'ano_publiacion': '2001-06-09', 'descripcion': 'Foot else though party red focus attack table. Charge little probably ever professor ahead. Choose at look show situation grow blue. Rather however majority letter bank avoid. Around administration re'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 973, 'tipo_publicacion': 'Give.', 'ano_publiacion': '2021-03-27', 'descripcion': 'Tough prepare subject together moment where education seven. Firm bag family south character list bill. Go growth policy trial out. True no save also economy president worker.'}, 'count_general_publicacions': 7}
# {'_id': {'publicacion_id': 920, 'tipo_publicacion': 'Whole arm.', 'ano_publiacion': '1986-11-28', 'descripcion': 'After goal create as sport task. Mouth read relate land. Stock minute ability of growth also Democrat. Dog picture another avoid here trouble learn. Its clear financial clearly traditional collection.'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 138, 'tipo_publicacion': 'Specific.', 'ano_publiacion': '2005-09-25', 'descripcion': 'Thing leader particularly could bill thing back. Yes box particular realize thank strong growth turn. Media send base nation environment. Democratic would somebody standard later. Pretty player well.'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 113, 'tipo_publicacion': 'Hospital.', 'ano_publiacion': '2005-06-05', 'descripcion': 'Or wall go follow number sound. Game decision point that. Year adult plan language concern.'}, 'count_general_publicacions': 12}
# {'_id': {'publicacion_id': 837, 'tipo_publicacion': 'Recognize.', 'ano_publiacion': '1988-07-25', 'descripcion': 'On special instead cultural common development family. Compare talk reveal I between success. Present approach teach add chance.'}, 'count_general_publicacions': 1}
# {'_id': {'publicacion_id': 796, 'tipo_publicacion': 'Million.', 'ano_publiacion': '1972-08-09', 'descripcion': 'Add why just morning system left left. Point late difficult film eight feel particular. Her part father class. Population entire either. Admit red technology position.'}, 'count_general_publicacions': 10}
# {'_id': {'publicacion_id': 315, 'tipo_publicacion': 'Money.', 'ano_publiacion': '2014-02-01', 'descripcion': 'Movement positive agent sit push customer. Simple magazine phone office several summer traditional body. Generation fine responsibility rich. Boy wind pressure pressure. Family itself red their. Event'}, 'count_general_publicacions': 8}
# {'_id': {'publicacion_id': 311, 'tipo_publicacion': 'System.', 'ano_publiacion': '1999-10-06', 'descripcion': 'Thought worker success which economy happen involve. Daughter term space. Others hot with build project western.'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 35, 'tipo_publicacion': 'Newspaper.', 'ano_publiacion': '1974-08-28', 'descripcion': 'Girl administration change compare treatment physical thought west. Artist community than note their. Hold team little nearly identify maybe else prevent. Despite law development popular past trial si'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 680, 'tipo_publicacion': 'Scientist.', 'ano_publiacion': '2019-04-03', 'descripcion': 'Let weight crime pass possible fill. His true spring painting day fly. Back choose special use safe indicate raise. Care decision recent cell certain consider. Tonight history wrong six crime. Attorne'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 265, 'tipo_publicacion': 'Ten sing.', 'ano_publiacion': '2023-03-02', 'descripcion': 'Than poor series view main. Difference poor really develop trade politics either. Spring toward alone memory fast method finally. Recognize father very another clear law right.'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 879, 'tipo_publicacion': 'Help.', 'ano_publiacion': '1992-03-27', 'descripcion': 'Cover language campaign life share sign. Capital method people today authority eye view. Audience son effect level. Six current produce throughout.'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 437, 'tipo_publicacion': 'Expect.', 'ano_publiacion': '1988-07-21', 'descripcion': 'Only eight realize wonder. Central here million. Stay long wear foot add.'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 89, 'tipo_publicacion': 'Phone.', 'ano_publiacion': '1992-05-29', 'descripcion': 'When partner would care network music. Put poor pick work son stop. While down feeling same area all. Before best stand represent interest water control.'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 672, 'tipo_publicacion': 'Relate.', 'ano_publiacion': '1988-02-16', 'descripcion': 'Box paper rather type. Range wait choice evening itself. Drive magazine culture require same American approach. Out our discuss need thing effort morning. Knowledge common need with difference althoug'}, 'count_general_publicacions': 8}
# {'_id': {'publicacion_id': 589, 'tipo_publicacion': 'Political.', 'ano_publiacion': '1974-08-11', 'descripcion': 'South effect contain stay else. Along stock current difference organization store. Race relationship live mission back itself all still. Forget after occur both fish show. Smile audience of arm.'}, 'count_general_publicacions': 1}
# {'_id': {'publicacion_id': 143, 'tipo_publicacion': 'Physical.', 'ano_publiacion': '2024-02-12', 'descripcion': 'Situation raise floor southern often town science. Southern accept job wish bed. May save hundred window decision political do quickly. Get environmental star attorney avoid another tend scientist. De'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 516, 'tipo_publicacion': 'Brother.', 'ano_publiacion': '1989-02-27', 'descripcion': 'Spring building clear again together event especially. Model stand member mind front. Follow eat prepare with seek against each. Happy once act keep partner year. Free eat fear professional industry f'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 717, 'tipo_publicacion': 'History.', 'ano_publiacion': '1992-11-30', 'descripcion': 'Suggest world write former accept. Once provide change. Fund far scene agent.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 709, 'tipo_publicacion': 'Capital.', 'ano_publiacion': '2019-11-11', 'descripcion': 'We fish tonight war. Determine month American boy. Else too bed. Treat occur loss bad once other more.'}, 'count_general_publicacions': 7}
# {'_id': {'publicacion_id': 465, 'tipo_publicacion': 'Other and.', 'ano_publiacion': '1986-04-30', 'descripcion': 'Care enough between. Look him address study maybe stuff wait. Democratic action prevent center policy throw.'}, 'count_general_publicacions': 12}
# {'_id': {'publicacion_id': 412, 'tipo_publicacion': 'Develop.', 'ano_publiacion': '2003-12-23', 'descripcion': 'Purpose mission need plan. Detail two wind behavior house individual debate western. Family field listen guess. Win benefit whatever any dark place bar candidate.'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 942, 'tipo_publicacion': 'Stop too.', 'ano_publiacion': '2008-09-27', 'descripcion': 'Ball within and carry phone offer successful. Garden also situation read food certainly blue. Notice artist visit.'}, 'count_general_publicacions': 12}
# {'_id': {'publicacion_id': 197, 'tipo_publicacion': 'Dream.', 'ano_publiacion': '2012-01-28', 'descripcion': 'Body discussion soldier. Site building situation figure situation article kitchen area. Cost former around agreement.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 356, 'tipo_publicacion': 'Seek find.', 'ano_publiacion': '1991-11-28', 'descripcion': 'Woman exactly region occur. Information final civil front. Within charge institution. Itself easy real get wall so. Have everything win.'}, 'count_general_publicacions': 9}
# {'_id': {'publicacion_id': 995, 'tipo_publicacion': 'Change.', 'ano_publiacion': '2022-11-07', 'descripcion': 'Avoid task much many difference eat knowledge. Challenge consumer check within time daughter. Across science occur above month agency. Check face letter. Either fall poor analysis phone.'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 503, 'tipo_publicacion': 'Only tree.', 'ano_publiacion': '1975-01-25', 'descripcion': 'Live fall Republican spend ball two watch. Especially field base treat grow onto. Owner how style chair happen trip. There federal condition as visit audience form.'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 145, 'tipo_publicacion': 'Should.', 'ano_publiacion': '1985-05-18', 'descripcion': 'Never talk success wall also. Or top check pattern task manager father start. Buy firm house weight through weight simple. Option behind few later sure within.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 166, 'tipo_publicacion': 'Market.', 'ano_publiacion': '1993-07-09', 'descripcion': 'Plant American person in arm. Do bad sense four nice bring. Stay growth attorney ever.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 230, 'tipo_publicacion': 'Price red.', 'ano_publiacion': '1977-05-17', 'descripcion': 'Week treat mean state rich. North college top approach body grow door. Store decade small first executive. Allow pretty against example manage name country. Western simple citizen commercial. Small se'}, 'count_general_publicacions': 2}
# {'_id': {'publicacion_id': 863, 'tipo_publicacion': 'Mention.', 'ano_publiacion': '2011-01-23', 'descripcion': 'Change front sign person happen treatment. Card style may which within. May realize anything scientist. Majority pass computer home big want budget surface. Peace court likely action collection. Try w'}, 'count_general_publicacions': 7}
# {'_id': {'publicacion_id': 544, 'tipo_publicacion': 'Art then.', 'ano_publiacion': '2012-03-13', 'descripcion': 'Either month before walk suddenly. General last avoid expert. His threat service cultural wind trouble. Benefit office say suffer lawyer commercial media. Green music all money head.'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 240, 'tipo_publicacion': 'Listen.', 'ano_publiacion': '2014-06-21', 'descripcion': 'Woman attorney news must. Final main thousand not once generation subject. Career far form though. Whatever total establish main pattern so service election.'}, 'count_general_publicacions': 7}
# {'_id': {'publicacion_id': 628, 'tipo_publicacion': 'South.', 'ano_publiacion': '2003-02-05', 'descripcion': 'Physical far site her language. Speech nice miss artist whom. Onto human fire heavy fund ground.'}, 'count_general_publicacions': 8}
# {'_id': {'publicacion_id': 593, 'tipo_publicacion': 'Hand.', 'ano_publiacion': '2006-06-15', 'descripcion': 'Place camera industry after people speech. Include real weight save herself score probably. Office fire provide specific discussion bag develop. Likely read music big. Particularly tough authority tea'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 579, 'tipo_publicacion': 'Must.', 'ano_publiacion': '1975-11-16', 'descripcion': 'Myself boy produce detail region until. Any sign within turn condition. Walk board practice never. Training join behavior sometimes. Officer goal glass indeed six often. Something garden avoid paper t'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 68, 'tipo_publicacion': 'Agree.', 'ano_publiacion': '1994-01-01', 'descripcion': 'Keep prove community assume huge question compare. Same record state resource. President feel ever executive government effort impact. Trip yard most give help world. Lead recent agree official once h'}, 'count_general_publicacions': 6}
# {'_id': {'publicacion_id': 871, 'tipo_publicacion': 'Ever ball.', 'ano_publiacion': '1971-06-14', 'descripcion': 'Rock soon top practice mission in large. Management spend foreign mother field pick either. Order fear yes store off. Total ball because not they state thank. Hit staff someone positive senior. Off fu'}, 'count_general_publicacions': 4}
# {'_id': {'publicacion_id': 703, 'tipo_publicacion': 'Though.', 'ano_publiacion': '2003-10-24', 'descripcion': 'Data quite first such decade defense finally. President hotel factor later me probably able. Strategy address inside evidence finish field. Image trip early state. Family Republican well worker pay di'}, 'count_general_publicacions': 9}
# {'_id': {'publicacion_id': 494, 'tipo_publicacion': 'Travel.', 'ano_publiacion': '1984-10-13', 'descripcion': 'Job section radio until major. Brother memory always evening threat order help order. Sister common player bit option that sometimes. Control four foreign explain medical budget debate.'}, 'count_general_publicacions': 5}
# {'_id': {'publicacion_id': 427, 'tipo_publicacion': 'Parent.', 'ano_publiacion': '2010-10-27', 'descripcion': 'Police off once opportunity material. Window fear party size spring final degree. Race fall thing way than wait actually. Paper goal when stock use system. Rise something deal last although. Sort diff'}, 'count_general_publicacions': 1}
# {'_id': {'publicacion_id': 960, 'tipo_publicacion': 'Firm.', 'ano_publiacion': '1974-03-29', 'descripcion': 'Prevent quality community head determine education along. Card style name agent let. Candidate sense wife include half expect. Natural far despite exist human. Unit firm leg which until opportunity go'}, 'count_general_publicacions': 12}
# {'_id': {'publicacion_id': 513, 'tipo_publicacion': 'Test.', 'ano_publiacion': '1998-08-10', 'descripcion': 'Ground become present scientist. Successful will conference. Often modern true professional body start floor.'}, 'count_general_publicacions': 12}
# {'_id': {'publicacion_id': 953, 'tipo_publicacion': 'Stop.', 'ano_publiacion': '2011-03-02', 'descripcion': 'On seek fine pull result entire. Gas attention level. Need result reveal position feel rock later international.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 169, 'tipo_publicacion': 'Weight.', 'ano_publiacion': '1979-07-13', 'descripcion': 'Job fear especially. Knowledge receive indeed six artist rise she. As see staff share goal. Establish politics commercial side before short. Military term to campaign year. Us character beyond choice '}, 'count_general_publicacions': 12}
# {'_id': {'publicacion_id': 630, 'tipo_publicacion': 'Program.', 'ano_publiacion': '1979-05-21', 'descripcion': 'Too amount structure. Movie cultural involve effort federal front. Ever here prove. Turn old executive back appear anything hard. Perhaps without debate under. Simple effect similar art amount.'}, 'count_general_publicacions': 3}
# {'_id': {'publicacion_id': 648, 'tipo_publicacion': 'Land.', 'ano_publiacion': '1973-05-29', 'descripcion': 'Blood conference small hospital. Amount ready address unit occur environment. Especially national culture head suddenly teach baby. Doctor any hot of.'}, 'count_general_publicacions': 1}

# %%
# Institución y cantidad de publicaciones

stage_group_institution_number_publications = {
  "$group": {
    "_id" : "$institucion_id.institucion_nombre",
    "count_publicaciones_x_institucion": {"$sum": 1}
  }
}

stage_out_institution_number_publications = {
  "$out": "out_num_publicaciones_x_institucion"
}

pipeline = [
  stage_group_institution_number_publications,
  stage_out_institution_number_publications
]

results = publicaciones.aggregate(pipeline)

for publications_by_intitutions_mapreduce in mdb["out_num_publicaciones_x_institucion"].find():
  print(publications_by_intitutions_mapreduce)
# Out:
# {'_id': 'Lucas-Hill', 'count_publicaciones_x_institucion': 4}
# {'_id': 'Miller, Valenzuela and Rogers', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Gonzalez LLC', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Ward, Smith and Moreno', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Dixon Inc', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Valencia, Wilson and Moran', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Cuevas and Sons', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Beard Group', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Boyd Group', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Leonard, Mitchell and Henderson', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Olson, Walters and Ray', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Wilkins-Johnson', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Williams, Foster and Williams', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Harper Ltd', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Davidson-Lee', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Spence-Farmer', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Wyatt Inc', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Holland-Mitchell', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Owens and Sons', 'count_publicaciones_x_institucion': 4}
# {'_id': 'Williams, Schmidt and Golden', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Thompson-Hall', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Murray, Mccann and Small', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Chapman, Sanchez and Harvey', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Rollins-Jackson', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Velasquez-Walker', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Fisher-Cook', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Martin, Kennedy and Durham', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Ryan-Howard', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Crawford Inc', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Kelley, Schneider and Barnes', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Rocha-Aguilar', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Francis-Hanson', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Taylor LLC', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Ford LLC', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Roman-Roach', 'count_publicaciones_x_institucion': 5}
# {'_id': 'Harrison PLC', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Horton-Howe', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Hunter, Garcia and Luna', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Vang-Meadows', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Ward Ltd', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Elliott, Bates and Hernandez', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Jefferson PLC', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Luna-Miller', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Harper-Vance', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Barnes-Leonard', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Valdez and Sons', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Vasquez-Armstrong', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Carroll-Randolph', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Russell LLC', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Williams-Spencer', 'count_publicaciones_x_institucion': 5}
# {'_id': 'Henry, Rodriguez and Riley', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Buck, Bauer and Robinson', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Ramirez, Wright and Gonzalez', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Brooks, Nunez and Mann', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Adams-Watson', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Edwards LLC', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Watson Group', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Townsend Ltd', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Roberts, Peterson and Peterson', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Garcia PLC', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Gardner-Hooper', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Jackson and Sons', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Chambers Inc', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Morgan-Reyes', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Roberts, Cohen and Bradley', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Branch-Roberts', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Williams Group', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Stone, Nguyen and Montgomery', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Horn PLC', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Roberson Ltd', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Davis and Sons', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Lynch Group', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Walker Group', 'count_publicaciones_x_institucion': 4}
# {'_id': 'Bass Inc', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Rice, Hardy and Hernandez', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Johnson PLC', 'count_publicaciones_x_institucion': 3}
# {'_id': None, 'count_publicaciones_x_institucion': 1196}
# {'_id': 'Daniels PLC', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Smith-Barber', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Leach-Jackson', 'count_publicaciones_x_institucion': 4}
# {'_id': 'Jones Group', 'count_publicaciones_x_institucion': 6}
# {'_id': 'Gutierrez-Russell', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Hernandez-Jordan', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Smith and Sons', 'count_publicaciones_x_institucion': 6}
# {'_id': 'Richards-Ray', 'count_publicaciones_x_institucion': 4}
# {'_id': 'Simmons, Butler and Martin', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Castro Ltd', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Nelson-Neal', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Fischer, Heath and Ramirez', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Foster PLC', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Acosta and Sons', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Estrada, Wu and Brown', 'count_publicaciones_x_institucion': 1}
# {'_id': 'White-Harper', 'count_publicaciones_x_institucion': 5}
# {'_id': 'Perry Inc', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Walker Ltd', 'count_publicaciones_x_institucion': 4}
# {'_id': 'Coleman, Jones and Brown', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Jones, Jones and Taylor', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Sloan-Powell', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Buchanan, Waters and Mejia', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Campbell Group', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Martin-Bass', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Taylor-Gonzales', 'count_publicaciones_x_institucion': 5}
# {'_id': 'Skinner, Lewis and Lewis', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Wade and Sons', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Meyers, Barnett and Sullivan', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Wise Ltd', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Schmidt, Mckay and Winters', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Odom, Lowery and Mckenzie', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Tanner Group', 'count_publicaciones_x_institucion': 4}
# {'_id': 'Turner-Smith', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Mcdonald, Estrada and Bradley', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Thomas-Myers', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Butler LLC', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Snyder-Neal', 'count_publicaciones_x_institucion': 4}
# {'_id': 'Willis, Mendez and Butler', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Guerrero, Williams and Simmons', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Sanford-Lawrence', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Rosario, Martinez and Garcia', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Sweeney-Boyer', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Kidd Inc', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Simmons, Caldwell and Peterson', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Gutierrez, Jones and Brown', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Green Ltd', 'count_publicaciones_x_institucion': 4}
# {'_id': 'Young and Sons', 'count_publicaciones_x_institucion': 6}
# {'_id': 'Rose-Lambert', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Lewis Group', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Humphrey Ltd', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Cunningham, Daniels and Fritz', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Bell, Mccall and Jimenez', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Hansen, Patterson and Garcia', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Greer, Cunningham and Hernandez', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Lewis, Martinez and Sherman', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Lee PLC', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Marquez-Gibson', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Rose, Gray and Holt', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Swanson PLC', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Neal-Walsh', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Donovan, Francis and Baxter', 'count_publicaciones_x_institucion': 4}
# {'_id': 'Hogan, Arias and Moore', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Walton Inc', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Sullivan Inc', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Galloway-Cook', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Logan and Sons', 'count_publicaciones_x_institucion': 7}
# {'_id': 'Alexander-Graves', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Lewis-Wells', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Boyer Ltd', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Patel, Duncan and Bryant', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Bailey and Sons', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Evans-Martinez', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Wilson-Santiago', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Alexander, Clark and Webb', 'count_publicaciones_x_institucion': 4}
# {'_id': 'Scott PLC', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Wyatt-Morton', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Ruiz LLC', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Bradley, Bartlett and James', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Carroll Inc', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Pearson Inc', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Johnson-Case', 'count_publicaciones_x_institucion': 6}
# {'_id': 'Johnson, Myers and Owens', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Anderson, Anderson and Herman', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Carter-Long', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Hobbs-Patterson', 'count_publicaciones_x_institucion': 6}
# {'_id': 'Haley-Andrews', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Hill PLC', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Sherman-Graham', 'count_publicaciones_x_institucion': 1}
# {'_id': 'James-Henderson', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Gates, Moss and Thompson', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Fowler-Cunningham', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Lee LLC', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Valencia, Smith and Davidson', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Benitez PLC', 'count_publicaciones_x_institucion': 6}
# {'_id': 'Bradshaw-Lin', 'count_publicaciones_x_institucion': 4}
# {'_id': 'Phillips PLC', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Lopez and Sons', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Taylor, Allen and Evans', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Hardy-Gonzalez', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Jones, Roberts and Hernandez', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Gonzalez, Mendez and Casey', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Durham PLC', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Thomas-Hunter', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Livingston, Humphrey and Green', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Myers-James', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Murphy, Brooks and Taylor', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Ochoa-Houston', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Cross-Collins', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Perez-Ayala', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Gregory-Ward', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Davis-Jones', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Valdez, Villegas and Allen', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Lopez PLC', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Kirby LLC', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Morgan-Walton', 'count_publicaciones_x_institucion': 3}
# {'_id': 'Burgess, Durham and Hernandez', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Smith Inc', 'count_publicaciones_x_institucion': 5}
# {'_id': 'Odom Ltd', 'count_publicaciones_x_institucion': 2}
# {'_id': 'Pearson and Sons', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Orozco-Arroyo', 'count_publicaciones_x_institucion': 1}
# {'_id': 'Sims-Robbins', 'count_publicaciones_x_institucion': 4}
# {'_id': 'Sexton Group', 'count_publicaciones_x_institucion': 1}

# %%
# Publicaciones por Sede

stage_group_publication_by_sede = {
  "$group": {
    "_id" : "$egresado_id.sede_nombre",
    "count_publications_by_sedes": {"$sum": 1} #count_publicaciones_x_institucion
  }
}

stage_out_publications_by_sede = {
  "$out": "out_num_publications_by_sede" # out_num_publicaciones_x_institucion
}

pipeline = [
  stage_group_publication_by_sede,
  stage_out_publications_by_sede
]

#results = publicaciones.aggregate(pipeline)
results = publicaciones.aggregate(pipeline)


for public_mapreduce in mdb["out_num_publications_by_sede"].find():
  print(public_mapreduce)
# Out:
# {'_id': 'PALMIRA', 'count_publications_by_sedes': 216}
# {'_id': 'TUMACO Y DE LA PAZ', 'count_publications_by_sedes': 199}
# {'_id': 'MANIZALES', 'count_publications_by_sedes': 200}
# {'_id': 'ORINOQUIA', 'count_publications_by_sedes': 190}
# {'_id': 'MEDELLÍN', 'count_publications_by_sedes': 193}
# {'_id': 'AMAZONIA', 'count_publications_by_sedes': 200}
# {'_id': 'CARIBE', 'count_publications_by_sedes': 209}
# {'_id': 'BOGOTÁ', 'count_publications_by_sedes': 182}

# %%
# Publicaciones por año

stage_group_year = {
  "$group": {
    "_id" : {"$year": {"$toDate": "$date_id"}},
    "count_publications_by_year": {"$sum": 1} # count_publications_by_year
  }
}

stage_out_year = {
  "$out": "out_num_publications_by_year" # out_num_publications_by_year
}

pipeline = [
  stage_group_year,
  stage_out_year
]

results = publicaciones.aggregate(pipeline)

for graduacion_mapreduce in mdb["out_num_publications_by_year"].find():
  print(graduacion_mapreduce)
# Out:
# {'_id': 2022, 'count_egresado': 6}
# {'_id': 1972, 'count_egresado': 33}
# {'_id': 2011, 'count_egresado': 16}
# {'_id': 2000, 'count_egresado': 8}
# {'_id': 1973, 'count_egresado': 4}
# {'_id': 1988, 'count_egresado': 48}
# {'_id': 2021, 'count_egresado': 35}
# {'_id': 1976, 'count_egresado': 10}
# {'_id': 2019, 'count_egresado': 46}
# {'_id': 2006, 'count_egresado': 26}
# {'_id': 2017, 'count_egresado': 74}
# {'_id': 1995, 'count_egresado': 12}
# {'_id': 2008, 'count_egresado': 28}
# {'_id': 1986, 'count_egresado': 19}
# {'_id': 2003, 'count_egresado': 33}
# {'_id': 1979, 'count_egresado': 32}
# {'_id': 2007, 'count_egresado': 41}
# {'_id': 1987, 'count_egresado': 20}
# {'_id': 1974, 'count_egresado': 46}
# {'_id': 1989, 'count_egresado': 26}
# {'_id': 1978, 'count_egresado': 30}
# {'_id': 1981, 'count_egresado': 21}
# {'_id': 1994, 'count_egresado': 18}
# {'_id': 1984, 'count_egresado': 49}
# {'_id': 1991, 'count_egresado': 12}
# {'_id': 2014, 'count_egresado': 52}
# {'_id': 1992, 'count_egresado': 37}
# {'_id': 1999, 'count_egresado': 41}
# {'_id': 2009, 'count_egresado': 35}
# {'_id': 2010, 'count_egresado': 45}
# {'_id': 1970, 'count_egresado': 12}
# {'_id': 1983, 'count_egresado': 24}
# {'_id': 2005, 'count_egresado': 52}
# {'_id': 1975, 'count_egresado': 41}
# {'_id': 2001, 'count_egresado': 37}
# {'_id': 1977, 'count_egresado': 58}
# {'_id': 1980, 'count_egresado': 47}
# {'_id': 2015, 'count_egresado': 27}
# {'_id': 1998, 'count_egresado': 33}
# {'_id': 1996, 'count_egresado': 8}
# {'_id': 2020, 'count_egresado': 8}
# {'_id': 1997, 'count_egresado': 34}
# {'_id': 1990, 'count_egresado': 9}
# {'_id': 1993, 'count_egresado': 23}
# {'_id': 2023, 'count_egresado': 31}
# {'_id': 2002, 'count_egresado': 27}
# {'_id': 1982, 'count_egresado': 13}
# {'_id': 2004, 'count_egresado': 6}
# {'_id': 2016, 'count_egresado': 43}
# {'_id': 2018, 'count_egresado': 27}
# {'_id': 2012, 'count_egresado': 59}
# {'_id': 2024, 'count_egresado': 4}
# {'_id': 1971, 'count_egresado': 17}
# {'_id': 1985, 'count_egresado': 29}
# {'_id': 2013, 'count_egresado': 17}
